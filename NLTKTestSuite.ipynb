# %% [markdown]
# Import required packages

# %%
import unittest, config, MySQLdb, pandas, warnings, numpy, nltk
from childes import CHILDESCorpusReader # import from nltk.corpus.reader for original

# %% [markdown]
# Connect to DB

# %%
chompsky_authenticator = config.Authenticator('Chompsky')
chompsky_con= MySQLdb.connect(host=chompsky_authenticator.host, 
                port=chompsky_authenticator.port,user=chompsky_authenticator.user, passwd=chompsky_authenticator.passwd, 
                db='childes')

# %% [markdown]
# Configure corpus & files to test

# %%
region = 'Eng-NA' # or Eng-UK
corpus_name = 'Sachs'
fileid_name = 'n02'

# %% [markdown]
# Set up corpus information

# %%
corpus_root = '/home/alsan/corpora/childes-xml/%s' % region
corpus = CHILDESCorpusReader(corpus_root, '%s/.*.xml' % corpus_name)
fileid = ['%s/%s.xml' % (corpus_name, fileid_name)]
filename = '/shared_hd0/corpora/childes_new/%s/n02.cha' % corpus_name

# %% [markdown]
# Test if words / sentences / mors in CHILDES-DB are equal to those outputted by NLTK reader

# %%
class NLTKTest(unittest.TestCase):
    
    def setUp(self):
        sql_words = " SELECT gloss, mor FROM words \
                      WHERE filename = %(filename)s "
        sql_sents = " SELECT DISTINCT sentgloss, sentmor FROM words \
                      WHERE filename = %(filename)s "
        
        self.words_df = pandas.read_sql(sql_words, chompsky_con, params={'filename':filename})
        self.sents_df = pandas.read_sql(sql_sents, chompsky_con, params={'filename':filename})
        
    def test_word_difference(self):
        words_db = self.words_df['gloss'].values.T.tolist()
        
        words_nltk = corpus.words(fileid)
                
        self.assertEqual(set(words_db), set(words_nltk))
            
    def test_word_mor_difference(self):
        word_mors_db = self.words_df['mor'].values.T.tolist()
        
        tagged_words_nltk = corpus.tagged_words(fileid, stem=True)
        word_mors_nltk = ['%s|%s' % p for p in tagged_words_nltk]
        
        self.assertEqual(set(word_mors_db), set(word_mors_nltk))
        
    def test_sent_difference(self):
        sents_db = self.sents_df['sentgloss'].values.T.tolist()
        
        sents_nltk = [" ".join(sent_arr) for sent_arr in corpus.sents(fileid)]
        
        self.assertEqual(set(sents_db), set(sents_nltk))
        
    def test_sent_mor_difference(self):
        sent_mors_db = self.sents_df['sentmor'].values.T.tolist()
        
        tagged_sents_nltk = corpus.tagged_sents(fileid, stem=True)
        sent_mors_nltk = [" ".join( ['%s|%s' % p for p in arr] ) for arr in tagged_sents_nltk]
        
        self.assertEqual(set(sent_mors_db), set(sent_mors_nltk))
        
def suite():
    test_suite = unittest.TestSuite()
    test_suite.addTest(unittest.makeSuite(NLTKTest))
    return test_suite

# %% [markdown]
# Run test suite

# %%
test_suite = suite()
runner=unittest.TextTestRunner()
runner.run(test_suite)
# Out:
# FFFF
# ======================================================================
# FAIL: test_sent_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-18-7379067e0323>", line 30, in test_sent_difference
#     self.assertEqual(set(sents_db), set(sents_nltk))
# AssertionError: Items in the first set but not the second:
# 'yes &ah &ah xxx pretty huh'
# 'they done'
# 'yyy &ah'
# '&um what are they'
# '&uh &uh yyy'
# '&ah'
# 'oh &uh ugh'
# "come on Naomi lie down I'm going to change your diaper &hmm"
# '&ah look Nomi a coloring book'
# '&um what are those'
# "&hmm what's that"
# '&eh &ah &ah oh'
# '&eh &ah'
# 'that'
# '&um yyy'
# '0'
# 'get that ball'
# '&um kitty'
# '&ah down'
# '&uh'
# '&hmm'
# '&um &um'
# 'what are you doing'
# 'oh &uh'
# 'they'
# '&ah oh baby'
# '&ah &ah &ah &ah &ah'
# 'yyy &hmm'
# 'he that'
# '&eh'
# '&eh &ah &eh &ah'
# '&mm'
# '&ah oh night_night'
# '&um'
# "&aw that's the easy way"
# Items in the second set but not the first:
# ''
# u'ah down'
# 'eh'
# u'um kitty'
# u'oh uh ugh'
# u'boydie birdie'
# u'eh ah'
# 'um'
# u'eh ah eh ah'
# u'sipper slipper'
# u'eh ah ah oh'
# u'ah look Nomi a coloring book'
# u'ah'
# u'yyy ah'
# u'he dat that'
# u'yyy hm'
# 'um yyy'
# u"come on Naomi lie down I'm going to change your diaper hm"
# u"hm what's that"
# u'ah ah ah ah ah'
# u'hm'
# u'um what are they'
# u'oh uh'
# u'ah oh night_night'
# u'yes ah ah xxx pretty huh'
# u'dat that'
# u'mm'
# u'dey dey they done'
# 'uh uh yyy'
# 'um um'
# u'dey they'
# u'um what are those'
# u'whatcha what are you doing'
# 'uh'
# u'get dat that ball'
# u"aw that's the easy way"
# u'ah oh baby'
# u'blankin blanket'
#
# ======================================================================
# FAIL: test_sent_mor_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-18-7379067e0323>", line 38, in test_sent_mor_difference
#     self.assertEqual(set(sent_mors_db), set(sent_mors_nltk))
# AssertionError: Items in the first set but not the second:
# 'v|look prep|at art|the n|bottom'
# 'BRK n:prop|Daddy'
# 'n|key'
# 'pro:dem|this cop|be&3S art|a n|windmill'
# 'co|whoopsie pro:exist|here~cop|be&3S art|a n|tissue prep|for pro|you'
# 'v|come adv|here coord|and v|look prep|at art|the n|book prep|with n:prop|Mommy'
# 'n|shoe'
# 'n:prop|Goldie adv|just mod|do&3S~neg|not v|want inf|to v|sit adv|in adv|there v|do&3S pro:sub|she'
# 'rel|that art|a n|girl'
# 'adj|good'
# 'EXC'
# 'n|brush'
# 'n|mouse rel|that~aux|be&3S n|baby n|mouse n:prop|Nomi'
# 'n|bacon'
# 'on|quack'
# 'adv:wh|where~cop|be&3S art|the n|moon'
# 'co|yes art|the n|baby aux|be&3S part|lie-PRESP n|down'
# 'adv:wh|where'
# 'BRK n|mouse'
# 'pro:wh|what~cop|be&3S pro:dem|that n|honey'
# 'v|get art|the n|red pro:indef|one'
# 'adv:wh|how BRK BRK n|house'
# 'bab|woo'
# 'co|yes coord|and n|girl'
# 'on|moo on|moo'
# 'pro:exist|here~cop|be&3S art|a n|boat'
# 'on|tweet on|tweet'
# 'conj|but mod|do~neg|not v|use pro|it adv|as art|a n|dust n|cloth n|+n|sweet+n|heart'
# 'adv|good&CP prep|to neg|not v|do pro|it prep|on art|the n|rug adv:wh|how~aux|be&3S det|that n|sweet&dadj-DIM'
# 'pro:sub|they mod|will~neg|not v|stay prep|on pro:poss:det|your n|ear-PL n:prop|Nomi'
# 'v|do'
# 'pro:dem|that~cop|be&3S adj|good pro:sub|I mod|can v|plug pro|it adv|right prep|in pro:dem|here'
# 'pro:sub|I v|want pro|you inf|to aux|be part|cover-PASTP prep|with pro:poss:det|your n|blanket'
# 'art|a n|ball'
# 'n:prop|Nomi v|come adv|on v|look prep|at art|the n|book v|look prep|at art|the n|book'
# 'n|down'
# 'co|boo'
# 'v|come adv|on pro:exist|here~cop|be&3S art|a n|diaper prep|in pro:dem|here n:prop|Naomi'
# 'EXC co|no co|oh'
# 'n|chimney'
# 'adv|there'
# 'adv:wh|where~cop|be&3S art|the n|house n:prop|Naomi'
# 'co|boy'
# 'v|see prep|at art|the n|bottom pro|you mod|can v|see n|fish'
# 'v|want inf|to v|put&ZERO art|the n|glass-PL adv|on'
# 'n|tree EXC n:prop|Daddy'
# 'n|green'
# 'co|yes co|yes adj|good n|girl'
# 'on|oig on|oig on|oig on|gu'
# 'pro:exist|here~cop|be&3S n:prop|Goldie'
# 'on|oink on|oink pro:exist|here~cop|be&3S art|a n|hat'
# 'pro:wh|what cop|be&3S det|this n|honey'
# 'aux|be&3S pro|it art|a n|blanket'
# 'n|mouse'
# 'n|doctor'
# 'mod|do~neg|not pro|you v|draw prep|on art|the n|baby'
# 'n:prop|Nomi pro:wh|what~cop|be&3S pro:dem|this'
# 'co|okay v|get art|the n|green det:num|one n:prop|Nomi'
# 'pro:exist|here~cop|be&3S art|a n|mouse'
# 'n|egg-DIM-PL'
# 'n|house co|yes'
# 'co|oh prep|up EXC'
# 'v|put&ZERO n:prop|Goldie prep|through art|the n|chimney'
# 'adj|good coord|and art|the n|bird-DIM v|say-3S'
# 'pro:wh|what~aux|be&3S art|the n|dog-DIM part|do-PRESP'
# 'n|baby n|hug'
# 'n|lie n|down adv|now'
# 'co|whoopsie'
# 'co|night_night n:prop|Naomi'
# 'v|come v|look prep|at art|the n|picture prep|of art|the n|horse'
# 'EXC EXC EXC'
# 'adj|bottom'
# 'n|moon co|yes pro:dem|that~cop|be&3S art|the n|moon'
# 'bab|lala'
# 'prep|up n|pen'
# 'bab|ba'
# 'co|uhhuh n|car'
# 'co|oh art|the n|blanket'
# 'n|money'
# 'pro|it v|fit-3S n:prop|Nomi'
# 'mod|can n:prop|Nomi v|say'
# 'pro:dem|this cop|be&3S art|the n|way art|the n|lady v|lie-3S n|lady v|lie-3S n|lady n|lie-PL'
# 'pro:dem|that~cop|be&3S adj|right on|moo'
# 'n|light-PL'
# 'EXC art|the adj|little n|drawer'
# 'pro:wh|what~cop|be&3S pro:dem|this art|the n|kitty aux|be&3S part|eat-PRESP n:prop|Nomi'
# 'n|fall n|down'
# 'n:prop|Mommy'
# 'mod|do~neg|not v|bang prep|on art|the n|glass'
# 'co|okay v|come adv|on v|let&ZERO pro:obj|me v|get pro|you EXC adv|here n|sweet&dadj-DIM adv|now'
# 'n|dog-DIM'
# 'mod|do pro|you v|want inf|to v|blow pro:poss:det|your n|nose'
# 'n:prop|Jerry'
# 'co|uhhuh'
# 'EXC adj|good'
# 'EXC mod|do pro|you v|want inf|to v|smell art|the n|flower n:prop|Nomi'
# 'co|say meta|slipper n:prop|Nomi'
# 'n:prop|Mommy~poss|s n|key'
# 'v|come prep|on n|play prep|with art|the n|mouse n|house'
# 'n|flower-PL v|smell art|the n|flower-PL'
# 'n|flower'
# 'v|look pro:sub|he aux|be&3S part|go-PRESP inf|to v|get prep|out_of art|the n|car'
# 'mod|do pro|you v|want inf|to v|look prep|at art|the n|book qn|some pro:indef|more'
# 'n:prop|Nomi mod|do~neg|not v|bang prep|on art|the n|glass'
# 'v|put&ZERO pro:poss:det|your n|arm adv|in'
# 'cop|be&PRES pro|you part|dance-PRESP n:prop|Nomi'
# 'n|block'
# 'adj|good n:prop|Nomi'
# 'co|oh rel|that cop|be&PAST&13S adj|good pro:sub|she v|get&PAST adv|all'
# 'pro:sub|I~mod|will v|get art|the qn|other n|slipper'
# 'EXC EXC EXC co|oh'
# 'pro:sub|I EXC'
# 'coord|and n:prop|Nomi v|say-3S'
# 'pro:dem|that~cop|be&3S adj|neat co|huh'
# 'n|snow'
# 'co|see v|want pro:obj|me inf|to v|wash pro:poss:det|your n|tooth&PL'
# 'co|yes art|the n|water n|baby v|live-3S adv|here'
# 'adj|okay adj|okay pro:exist|here~cop|be&3S art|the n|crayon'
# 'n|cookie'
# 'pro|it cop|be&3S adj|empty'
# 'mod|can pro|you v|find art|a n|fish'
# 'on|woof on|woof'
# 'co|say co|yeah'
# 'EXC pro:obj|me adv|up'
# 'adv|up'
# 'pro|it~aux|be&3S adj|good&CP inf|to v|build pro|it adv|on adv|here n|honey rel|where art|the n|floor cop|be&3S'
# 'co|oh EXC co|ugh'
# 'co|oh mod|do pro:sub|they v|smell adj|nice'
# 'adj|green n|light'
# 'v|remember pro:sub|we v|see&PAST n|snow'
# 'EXC co|oh n|baby'
# 'pro:wh|what v|do&3S art|the n|chick-DIM v|say n|sweet&dadj-DIM'
# 'pro:exist|there~cop|be&3S pro:indef|one pro:indef|more'
# 'v|want inf|to v|go v|see art|the n|snow'
# 'n:prop|Little_Red_Riding_Hood n:prop|Little_Red_Riding_Hood prep|on pro:poss:det|her n|way prep|to n:prop|Grandmother~poss|s n|place'
# 'v|wait n:prop|Nomi'
# 'pro:wh|what aux|be&PRES pro|you part|do-PRESP'
# 'n|shingle mod|can pro|you v|say'
# 'v|fit-3S'
# 'cop|be'
# 'n|ball'
# 'on|woof on|woof on|woof'
# 'on|neheeheeheeheehee'
# 'n:prop|Nomi co|no'
# 'v|want inf|to v|give n:prop|Mommy art|a n|hug'
# 'n|cow'
# 'n|pig-DIM adj|right'
# 'on|peep on|peep'
# 'n|crane'
# 'art|a n|cow'
# 'pro:dem|that~cop|be&3S neg|not art|the n|moon'
# 'pro:sub|they'
# 'pro:wh|what~aux|be&3S cop|be&3S det|this n|thing'
# 'co|night_night n|+n|sweet+n|heart'
# 'BRK BRK BRK BRK BRK n:prop|Nomi v|say'
# 'det|this pro:indef|one adv|here'
# 'pro|it~cop|be&3S art|a n|bird-DIM'
# 'co|oh pro|you v|want n|diaper n:prop|Nomi'
# 'adv:wh|where~cop|be&3S art|the n|pig-DIM'
# 'adv|now adv:wh|how mod|do pro|you v|say'
# 'v|put&ZERO n|baby prep|in art|the n|boat'
# 'co|oh art|a adj|little n|drawer'
# 'adv:wh|where~cop|be&3S n|dog-DIM~poss|s n|tail'
# 'pro:dem|that~cop|be&3S art|a n|horse'
# 'co|whoops'
# 'pro:wh|what EXC'
# 'bab|gaga'
# 'adv:wh|where~cop|be&3S art|the adv:wh|where~cop|be&3S art|the n|hole n:prop|Nomi'
# 'n|walrus'
# 'chi|payn'
# 'n|hut'
# 'n:prop|Goldie'
# 'art|a n:prop|Little_Miss_Muffet n:prop|Little_Miss_Muffet v|sit&PAST prep|on pro:poss:det|her n|tuffet part|eat-PRESP pro:poss:det|her n|curd-PL coord|and n|whey adv|along v|come&PAST art|a'
# 'pro:wh|what aux|be&PRES pro|you part|do-PRESP n:prop|Nomi'
# 'pro:dem|this cop|be&3S art|a n|nut'
# 'adv:wh|where~cop|be&3S art|the n|rabbit'
# 'on|eueueu'
# 'n:prop|Nomi v|say'
# 'art|a n|book'
# 'pro:sub|I~aux|be&1S part|try-PRESP inf|to v|get n|word-PL prep|with n:let|b-PL coord|and n:let|p-PL adv|now'
# 'n:prop|Mammy'
# 'n|pig-DIM'
# 'v|come prep|on n:prop|Naomi n|lie adv|down pro:sub|I~aux|be&1S part|go-PRESP inf|to v|change pro:poss:det|your n|diaper EXC'
# 'co|no pro:dem|that~cop|be&3S neg|not art|the n|noon n:prop|Naomi'
# 'n|pen'
# 'pro:dem|that'
# 'co|yes n:prop|Daddy'
# 'pro:dem|this cop|be&3S art|a n|slipper'
# 'pro|it~cop|be&3S n|money'
# 'pro:exist|here~cop|be&3S art|the n|horse-DIM'
# 'bab|gaga bab|bim'
# 'n|eye'
# 'co|yeah pro|it v|fit-3S'
# 'pro:indef|nothing prep|in pro:dem|there'
# 'co|no pro|you v|lie n|down post|too'
# 'co|okay n|pig-DIM'
# 'pro:dem|this cop|be&3S art|a adj|big n|shoe'
# 'n|pot-DIM'
# 'co|yes pro:dem|that~cop|be&3S art|a adj|good n|girl'
# 'v|put&ZERO art|the n|coat prep|over pro:dem|here'
# 'pro:exist|there~cop|be&3S n:prop|Goldie adv|again'
# 'pro:sub|I~mod|will v|bring art|the n|paper'
# 'v|come prep|on pro:wh|what~aux|be&3S rel|that n:prop|Nomi'
# 'pro|it~aux|be&3S n:prop|Goldie'
# 'n|dog-DIM co|yeah'
# 'mod|can pro|you v|find qn|some n|bird-PL n:prop|Nomi'
# 'pro|it v|turn adj|good'
# 'adv|here'
# 'co|yes adj|good'
# 'n:prop|Nomi n|lie n|down post|too'
# 'v|look pro:wh|what cop|be&3S adv|here n|sweet&dadj-DIM'
# 'co|remember'
# 'n:prop|Nomi mod|can pro|you v|say'
# 'EXC EXC EXC EXC'
# 'v|put&ZERO n:prop|Goldie prep|through art|the n|chimney n|honey v|put&ZERO n:prop|Goldie prep|through art|the n|chimney'
# 'mod|can pro|you v|say'
# 'v|show pro:obj|me art|a n|tower v|show pro:obj|me art|a n|tower n|tower'
# 'n|kangaroo n|kangaroo'
# 'co|oh n|honey'
# 'adv|there pro:sub|she v|go-3S'
# 'cop|be&3S art|the n|dog-DIM part|smell-PRESP'
# 'co|no pro|it~cop|be&3S neg|not art|a n|cow'
# 'co|good_night n|baby pro|you v|get adv|up conj|when pro|you v|want prep|to adj|okay'
# 'pro:obj|me adv|down adv|up'
# 'pro:wh|what aux|be&PRES det|these n|thing-PL prep|in pro:dem|here n:prop|Nomi'
# 'pro:sub|they part|do&PASTP'
# 'pro:wh|what n|kind prep|of n|bird-DIM'
# 'v|come prep|on chi|gogo'
# 'aux|be&3S pro|it n:prop|Goldie'
# 'pro:wh|what~cop|be&3S pro:dem|this n:prop|Naomi rel|who cop|be&3S pro:dem|that'
# 'co|no pro|it~cop|be&3S art|a n|baby'
# 'n|house'
# 'on|moo'
# 'n|hug'
# 'cop|be&3S rel|that art|a n|hat'
# 'n|glass-PL'
# 'pro:dem|that~cop|be&3S adj|dangerous n:prop|Nomi'
# 'BRK n|hat'
# 'n|doll-DIM~aux|be&3S part|stick-PRESP adv|up prep|over pro:dem|there'
# 'pro:dem|that cop|be&3S rel|where art|the adj|beautiful n|princess v|live-3S n:prop|Nomi'
# 'cop|be&3S pro:sub|she part|say-PRESP n|monkey'
# 'n|rabbit'
# 'n|windmill'
# 'qn|no n|horse-DIM v|say-3S on|eheeheeheehee'
# 'mod|can pro|you v|say meta|pupil n:prop|Nomi'
# 'n|book pro|it'
# 'n|foot-DIM n|rock'
# 'n|slipper'
# 'qn|no art|the n|chick-DIM v|say-3S on|peep on|peep on|peep'
# 'bab|doodie'
# 'art|the n|city prep|of n:prop|Burning n:prop|Towers'
# 'v|brush art|the n|baby~poss|s n|hair'
# 'cop|be bab|bit'
# 'pro:wh|what n:prop|Nomi'
# 'pro|you v|have det:num|one det:num|two det:num|three'
# 'n|baby co|yeah'
# 'mod|do pro|you v|have art|the n|slipper'
# 'n|squirrel'
# 'n:prop|Daddy n|play'
# 'n|doll-DIM~aux|be&3S part|take-PRESP art|a n|nap'
# 'pro:wh|who cop|be&3S pro:dem|that'
# 'v|come adv|up adv|here art|a n|minute prep|with pro:obj|me'
# 'n:prop|Mommy art|a n|hug v|come v|give n:prop|Mommy art|a n|hug'
# 'co|no'
# 'art|a n|brush'
# 'on|oig on|ag on|oig on|oig on|oig on|oig'
# 'pro:dem|that~cop|be&3S adv|too adj|big prep|to n|push n:prop|Nomi'
# 'v|give pro:obj|me art|a n|kiss coord|and pro:sub|I~mod|will v|get art|the EXC prep|for pro|you'
# 'EXC pro:wh|what aux|be&PRES pro:dem|those'
# 'v|put&ZERO n:prop|Goldie prep|in art|the n|house'
# 'n|owl'
# 'pro:wh|what aux|be&PRES det|these n|+n|sweet+n|heart'
# 'n|cone'
# 'adv|ill'
# 'co|yes pro:wh|what~aux|be&3S art|the n|kitty adv|in adv|here'
# 'adv:wh|where~cop|be&3S art|the n|baby'
# 'pro:exist|there~cop|be&3S art|the n|red pro:indef|one'
# 'n|milk n|kitty-PL v|eat n|cheese'
# 'co|okay n|pin'
# 'n|pig-DIM v|say-3S on|oink on|oink'
# 'pro:wh|what~aux|be&3S art|a n|pig-DIM v|say'
# 'art|a n|house'
# 'n:prop|Nomi adv:wh|where cop|be&3S n:prop|Mama n|mouse'
# 'mod|do pro|you v|know pro:wh|what qn|any prep|of pro:dem|those cop|be&PRES'
# 'BRK n|duck'
# 'rel|who'
# 'co|okay co|say'
# 'pro:obj|me adv|down'
# 'n|queen n|queen'
# 'n:prop|Nana'
# 'co|alright n:prop|Nomi pro:sub|I v|want pro|you prep|to n|nap adv|now'
# 'n|car'
# 'v|say pro|it adv|again n|sweet&dadj-DIM'
# 'mod|can pro|you v|say rel|that'
# 'pro:sub|he pro:dem|that'
# 'mod|do pro|you v|want inf|to v|beep pro:poss:det|my n|nose'
# 'co|okay co|sweetie v|let~pro:obj|us v|look prep|at art|the n|book qn|some pro:indef|more'
# 'n|tea prep|in art|the n|chimney'
# 'co|ahhah n|baby coord|and pro:exist|there~cop|be&3S art|a n:prop|Mommy'
# 'co|good_night'
# 'co|no pro:dem|that~cop|be&3S art|the n|blue pro:indef|one'
# 'adj|blue'
# 'v|get art|the n|green det:num|one adv|over adv|there'
# 'BRK BRK adv|up coord|and adv|up'
# 'mod|do pro|you v|want det|this pro:indef|one adv|on'
# 'pro:exist|there~cop|be&3S art|the n|hat'
# 'pro:dem|that~cop|be&3S pro:poss:det|your n|foot'
# 'coord|and pro:wh|what v|do&3S art|the n|horse-DIM v|say'
# 'pro:exist|here~cop|be&3S art|the n|moon'
# 'co|whoo'
# 'n|boot'
# 'v|look pro:wh|who cop|be&3S pro:dem|that'
# 'pro:wh|what aux|be&PRES det|these n|thing-PL EXC n|fish'
# 'v|do&PAST pro|you v|go prep|to art|the n|doctor adv:tem|today'
# 'adj|good n|baby'
# 'n|foot-DIM'
# 'pro|it v|happen-3S inf|to cop|be art|the n:prop|Chicago EXC coord|or pro:indef|something pro:dem|that~aux|be&3S art|a adj|big n|house'
# 'n:prop|Daddy'
# 'pro:dem|that~cop|be&3S art|a n|house adv|too co|yes'
# 'EXC pro:wh|what~cop|be&3S pro:dem|that'
# 'pro:wh|what cop|be&3S det|this n:prop|Nomi'
# 'conj|like n:prop|Mommy aux|have&3S adv|on'
# 'adv:wh|how~aux|be&3S det|that n|tower'
# 'bab|boo'
# 'co|yes pro:dem|that~cop|be&3S art|the n|dog-DIM'
# 'n|horse-DIM'
# 'n:prop|Dadda'
# 'pro:sub|they mod|will v|feel art|a n|lot adj|good&CP part|close-PASTP'
# 'co|yes pro:dem|that~cop|be&3S n|right'
# 'v|read&ZERO art|a n|book'
# 'n|monkey'
# 'BRK bab|woo'
# 'v|look n:prop|Nomi art|the n|car mod|do&3S~neg|not v|have qn|any n|wheel-PL prep|on pro|it'
# 'co|okay adv|now pro:sub|I v|want pro|you inf|to v|say v|say'
# 'pro:exist|here~cop|be&3S art|a n|kitty'
# 'adv|there pro:sub|she aux|be&3S co|yes'
# 'part|break&PASTP'
# 'v|put&ZERO adv|down'
# 'co|okay'
# 'v|go adj|wee'
# 'co|okay n|blanket'
# 'v|see art|the n|baby'
# 'v|see n:prop|Mommy'
# 'co|ahhah coord|and art|a n|cow v|say-3S'
# 'co|yeah'
# 'pro:dem|that~cop|be&3S art|a n|city'
# 'pro:dem|that~cop|be&3S n:prop|Nomi'
# 'BRK n|truck'
# 'pro:sub|I v|think adv|maybe n:prop|Mama~aux|be&3S part|come-PRESP n|home'
# 'n|fish'
# 'EXC n|down'
# 'pro:exist|there~cop|be&3S art|a n|dog-DIM'
# 'on|ahu'
# 'n:prop|Daddy~aux|be&3S part|go-PRESP inf|to v|bring art|the n|paper n|honey'
# 'pro:sub|I v|think&PAST det|those cop|be&PAST prep|among art|the n|thing-PL rel|that pro|you v|put&ZERO adv|away'
# 'adv:wh|how adj|big aux|be&3S'
# 'n|hat co|yes'
# 'pro:dem|that~cop|be&3S art|the n|red pro:indef|one'
# 'det:wh|what v|do n|kitty-PL v|eat'
# 'BRK adv:wh|how'
# 'pro:wh|what cop|be&PAST&13S rel|that n:prop|Naomi'
# 'n|boat'
# 'pro|you mod|can v|see art|a n|car adv|out rel|that n|window'
# 'adj|chic'
# 'coord|and pro:exist|here~cop|be&3S art|the n|spider'
# 'n|lie prep|down n:prop|Naomi conj|so pro:sub|we mod|can v|change pro:poss:det|your n|diaper'
# 'pro:sub|we v|have art|a n|disaster conj|if pro|you v|bang prep|on art|the n|glass'
# 'qn|no n|red pro:indef|one adj|first n:prop|Nomi'
# 'n|kiss n|baby'
# 'n|gun'
# 'n|play prep|with art|the n|bird-DIM'
# 'co|yeah pro:dem|that~cop|be&3S n:prop|Contrary_Mary~poss|s n|garden'
# 'EXC co|oh co|night_night'
# 'mod|can pro:sub|she v|reach pro:dem|this'
# 'co|yes adv|there pro|it cop|be&3S'
# 'n|horse'
# 'pro:wh|what~aux|be&3S rel|that n:prop|Naomi'
# 'pro:dem|that~cop|be&3S adj|right n|bird-PL cop|be&PRES adv|there'
# 'EXC on|oig on|oig'
# 'pro:exist|there~cop|be&3S art|the n|bird-DIM'
# 'cop|be&3S n:prop|Nomi part|write-PRESP art|the n|dog~poss|s n|tail'
# 'co|okay adv|now v|say'
# 'prep|up n|down'
# 'EXC n|pen'
# 'BRK BRK n|car'
# 'qn|no n|+n|sweet+n|heart pro|you adv|just v|go&PAST n|pot-DIM'
# 'n|box'
# 'pro:wh|what aux|be&3S det|this'
# 'pro:wh|what~aux|be&3S part|break&PASTP n:prop|Nomi'
# 'n|ear'
# 'pro:wh|what'
# 'prep|at art|the n|bottom n:prop|Nomi'
# 'EXC mod|do pro|you v|want inf|to v|turn pro:dem|that'
# 'chi|petty'
# 'det:wh|what aux|be&PRES pro:sub|they part|eat-PRESP'
# 'co|yes coord|and pro:dem|these cop|be&PRES n|chick-DIM-PL'
# 'pro:dem|that~cop|be&3S EXC n|slipper'
# 'co|well v|let~pro:obj|us v|have qn|some n:let|d n:let|i n:let|n n:let|n n:let|e n:let|r'
# 'co|yes n:prop|Mommy coord|and art|a n:prop|Daddy'
# 'co|okay v|say pro|it adv|again'
# 'n:prop|Flipper'
# 'n:prop|Nomi v|need-3S adj|big-CP n|ear-PL'
# 'on|oug on|oug'
# 'pro:sub|she v|say-3S n|shoe adv|very adv|nice&dadj-LY adv|now'
# 'pro:wh|what~cop|be&3S pro:dem|that'
# 'adj|poor n:prop|Goldie'
# 'co|yes coord|and pro:exist|here cop|be&3S art|a n|kitty'
# 'n|knock n|knock n|knock co|knock'
# 'n|baby aux|be&3S part|take-PRESP art|a n|nap'
# 'n|dog-DIM EXC'
# 'co|yes EXC EXC EXC adv|pretty co|huh'
# 'adj|empty'
# 'pro:dem|that~cop|be&3S art|a n|kitty co|huh'
# 'pro:dem|that~cop|be&3S adj|dangerous'
# 'n:prop|Naomi v|get&PAST adv|up adv|already'
# 'n|stay prep|in pro:dem|here n:prop|Daddy~aux|be&3S part|go-PRESP inf|to v|bring art|the n|paper'
# 'chi|peggie chi|ban'
# 'adj|sure'
# 'pro|you v|lie adv|down adv|too pro|you v|lie adv|down prep|with art|the n|baby'
# 'mod|do pro:sub|they v|smell adv|pretty'
# 'co|boy BRK BRK adj|big'
# 'n|baby BRK n|duck'
# 'v|let~pro:obj|us v|call pro|it EXC v|say n|shoe'
# 'n|book'
# 'pro|you adv|just v|go&PAST n|pot-DIM adv|now pro|it cop|be&3S v|time inf|to v|go prep|to n|sleep'
# 'n|tea'
# 'NO_UTT'
# 'v|tell pro:obj|me adv|again pro:wh|what aux|be&3S det|this'
# 'n|rock'
# 'n|paper'
# 'adv|here pro|you v|go'
# 'n|bear'
# 'pro:dem|that~cop|be&3S art|a n|baby'
# 'pro:dem|that~cop|be&3S art|a n|walrus'
# 'n:prop|Daddy n|dog-DIM'
# 'adj|care&dn-FULL'
# 'cop|be&PRES pro|you part|ride-PRESP pro:poss:det|your chi|gogo'
# 'v|lie pro:obj|me adv|down'
# 'co|yes n:prop|Goldie v|write prep|down n:prop|Goldie'
# 'bab|gala'
# 'bab|ca'
# 'chi|cam'
# 'pro:dem|that~cop|be&3S art|the n|tongue'
# 'pro:dem|that~cop|be&3S pro:poss:det|your n|ear'
# 'n|chicken'
# 'EXC n|baby'
# 'n|chick-DIM'
# 'v|get adv|down'
# 'pro:exist|here~cop|be&3S art|the n|tail n:prop|Nomi'
# 'pro:wh|what pro:obj|me prep|to co|help'
# 'n|blanket n:prop|Nomi'
# 'v|go prep|in art|the n|kitchen coord|and v|see n:prop|Daddy'
# 'co|yes n|snow prep|at art|the n|window co|huh'
# 'co|yes rel|that cop|be&3S art|a n|house'
# 'adv|again'
# 'n|puppy'
# 'v|bite&PAST conj|but'
# 'co|byebye'
# 'pro:sub|he aux|be&3S part|go-PRESP prep|to n|turn prep|off art|the n|light-PL'
# 'n|baby'
# 'co|yeah co|well pro:dem|that~cop|be&3S pro:wh|what pro:sub|I v|think&PAST'
# 'n|nut'
# 'aux|be&3S pro|it art|a n|chicken'
# 'chi|hutch'
# 'co|uhhuh n|kitty'
# 'co|uhhuh n|duck'
# 'co|whoops n:prop|Goldie v|fall&PAST adv|out'
# 'pro:wh|what~cop|be&3S pro:dem|this'
# 'mod|do pro|you v|want art|a n|crayon'
# 'cop|be&3S art|the n|horse-DIM aux|be-PRESP co|careful'
# 'pro:dem|that~cop|be&3S art|a n|ball'
# 'on|ahuhuhu'
# 'v|eat'
# 'on|oig on|oig on|oig EXC'
# 'pro:sub|she v|go&PAST coord|and v|get&PAST art|the n|diaper prep|after n:gerund|say-PRESP meta|dupper coord|or pro:wh|what adv|ever pro|it cop|be&PAST&13S'
# 'adv|up prep|down pro:poss:det|your part|dance-PRESP'
# 'on|beep'
# 'n|turn co|yes'
# 'pro:sub|they aux|be&PRES part|call-PASTP n|glass-PL'
# 'adv:wh|where~cop|be&3S art|the n|blanket'
# 'pro|it~cop|be&3S art|a n|horse'
# 'n|kitty-PL v|eat n|milk'
# 'BRK n|house'
# 'EXC adj|kit&dn-Y'
# 'pro|you adv|still mod|do~neg|not v|have pro:poss:det|your n|slipper prep|on n|babe'
# 'pro:wh|who~cop|be&3S pro:dem|that n|sweet&dadj-DIM'
# 'n|push'
# 'pro:sub|he art|a n|pot-DIM'
# 'BRK adv|pretty'
# 'chi|bam'
# 'pro:poss|mine'
# 'mod|do pro|you v|remember pro:wh|what art|the n|horse-DIM v|say-3S'
# 'n|snow co|yes adj|pretty n|snow'
# 'n|brush n|brush'
# 'pro:dem|that~cop|be&3S pro:wh|what art|the n|pig-DIM v|say-3S on|oink on|oink co|yeah'
# 'pro:sub|I v|think n:prop|Mama~poss|s part|come-PRESP prep|up art|the n|stair-PL'
# 'pro:wh|what v|do&3S art|the n|dog-DIM v|say'
# 'part|dance-PRESP'
# 'adv:wh|how co|oh'
# 'co|night_night'
# 'pro:wh|what aux|be&PRES pro:dem|those'
# 'co|no co|no'
# 'n|horse-DIM adv|right v|want inf|to v|build art|a n|tower'
# 'n|hug co|yeah'
# 'adj|dangerous n:prop|Nomi'
# 'adj|red pro:indef|one'
# 'adv:wh|how'
# 'pro:wh|what~cop|be&3S pro:dem|this n:prop|Nomi'
# 'adv:wh|where~cop|be&3S art|a n|fish n:prop|Nomi'
# 'EXC EXC EXC EXC EXC'
# 'v|let&ZERO pro:obj|me v|see'
# 'cop|be&3S adv|there art|a n|mouse prep|in pro:dem|there'
# 'n:prop|Goldie v|fall&PAST adv|down'
# 'v|look prep|at pro:dem|that'
# 'co|yes rel|that cop|be&3S n:prop|Nomi prep|in art|the n|mirror'
# 'n|girl'
# 'co|oh co|oh v|look prep|at pro|it v|spin'
# 'pro:wh|what v|do&3S art|the n|pig-DIM v|say'
# 'co|whoopsie n:prop|Goldie v|fall&PAST adv|down adv|again'
# 'n|bun'
# 'co|okay pro:dem|that~cop|be&3S adj|nice'
# 'pro:sub|she~cop|be&3S'
# 'n|pupil-PL pro:wh|what~poss|s art|a n|pupil'
# 'co|oh'
# 'n:prop|Jerry v|make&PAST rel|that'
# 'EXC v|look n:prop|Nomi art|a part|color-PRESP n|book'
# 'v|get adv|down adj|okay'
# 'n|mouse pro:dem|that~aux|be&3S neg|not art|a n|mouse n:prop|Nomi pro:dem|that~cop|be&3S art|a n|house'
# 'n|vase'
# 'n|cow n|cow v|jump-PAST prep|over art|the n|moon v|read&ZERO n:prop|Little_Miss_Muffet'
# 'n|spoon adv:wh|where~cop|be&3S art|the n|spoon'
# 'co|uhhuh n|button'
# 'co|oh n|slipper'
# 'qn|no n|boot'
# 'co|ow'
# 'v|go v|find v|get art|the n|doll-DIM coord|and v|brush art|the n|doll-DIM~poss|s n|hair'
# 'pro:exist|here~cop|be&3S qn|another n|horse n:prop|Nomi'
# 'co|night_night n|sweet&dadj-DIM'
# 'pro|you v|lie adv|down adv|too prep|with art|the n|baby'
# 'n|tissue'
# 'n|cheese co|yeah'
# 'adj|kit&dn-Y'
# 'v|sit prep|down n|brush n|hair'
# 'pro|it mod|do&3S~neg|not v|fit&ZERO'
# 'qn|no n|red pro:indef|one adj|first'
# 'mod|will pro|you v|come adv|in adv|here coord|and BRK BRK BRK BRK BRK pro:sub|we~mod|will v|play prep|with art|the n|mouse n|house'
# 'adj|good n|puppy'
# 'v|come adv|on prep|in pro:dem|here'
# 'n|pin'
# 'v|fall&PAST adv|down'
# 'n:prop|Naomi n|brush n:prop|Naomi part|brush-PRESP'
# 'pro:dem|this cop|be&3S art|the n|tongue n:prop|Nomi'
# 'adj|purple'
# 'n|table'
# 'EXC pro:dem|that~cop|be&3S art|the adj|ease&dn-Y n|way'
# 'n|pillow'
# 'co|no pro:sub|I mod|do~neg|not v|think co|so'
# 'co|oh art|the n|glass-PL aux|be&PRES part|break&PASTP'
# 'cop|be n|care-FUL adv|now pro|you~mod|will part|hit&PASTP pro:poss:det|your n|head'
# 'n:prop|Nomi'
# 'adv|here v|let~pro:obj|us v|put&ZERO pro|it v|like pro:dem|this conj|so pro:sub|she mod|will~neg|not v|fall adv|again'
# 'co|whoo v|woo'
# 'co|huh'
# 'art|the n|donkey aux|be&3S part|dance-PRESP part|dance-PRESP part|dance-PRESP'
# 'art|a adj|empty n|drawer'
# 'v|go co|night_night'
# 'v|put&ZERO pro:poss:det|your n|head n|down'
# 'v|leave pro|it adv|over adv|here conj|while pro:sub|we~cop|be&PRES neg|not part|use-PRESP pro|it'
# 'co|uhhuh v|say pro|it adv|again'
# 'n|foot'
# 'pro:dem|that~cop|be&3S adj|neat rel|that pro|you v|turn pro|it coord|and pro|it v|let-3S pro|it v|go'
# 'adv|pretty adj|big'
# 'mod|do pro|you v|put&ZERO pro:dem|this prep|on art|the n|floor n:prop|Nomi'
# 'n:prop|Nomi pro:dem|this cop|be&3S art|a n|vase'
# 'v|go prep|to art|the n|door prep|in art|the n|kitchen prep|in art|the n|kitchen n|honey'
# 'co|yes rel|that cop|be&3S pro:wh|what art|the n|horse-DIM v|say-3S'
# 'v|fall&PAST adv|down adv|again'
# 'pro:sub|she adv|never v|realize-3S adv:wh|how adj|big art|a n|piece'
# 'n|shingle'
# 'adj|kit&dn-Y n:gerund|eat-PRESP'
# 'v|put&ZERO n:prop|Goldie prep|through art|the n|chimney n|honey'
# 'det:num|one n|mouse'
# 'n|ear adv:wh|where~cop|be&3S n|dog-DIM'
# 'co|oh n:prop|Nomi'
# 'n:prop|Naomi pro:wh|what~cop|be&3S pro:dem|that'
# 'art|a on|oig BRK BRK art|a on|oig on|oig'
# 'mod|do~neg|not v|draw co|no co|no mod|do~neg|not v|draw'
# 'cop|be&3S det|this pro:poss:det|your n|slipper'
# 'pro:dem|that~cop|be&3S n|right'
# 'co|whoops qn|another pro:indef|one part|miss-PRESP'
# 'v|do&PAST pro|you v|lose art|a n|crayon co|honey'
# 'on|meow on|meow'
# 'co|say'
# 'coord|and pro:wh|what v|do&3S art|a n|chick-DIM v|say'
# 'adv:wh|where~cop|be&3S art|the n|bird-DIM'
# 'pro:exist|there~cop|be&3S art|the n|paper n|honey coord|and art|the n|book'
# 'n|beep'
# 'qn|no n|ear n:prop|Nomi'
# 'BRK bab|gaga'
# 'conj|if pro|you v|want inf|to v|call pro|it rel|that pro|it~cop|be&3S adj|fine prep|with pro:obj|me'
# 'BRK pro:sub|they part|do&PASTP'
# 'adj|good n|kiss'
# 'v|see'
# 'adj|lay n|down'
# 'pro:sub|I v|think n:prop|Nomi aux|be&3S part|tire-PASTP'
# 'BRK on|oig bab|ye'
# 'art|a n|puppy'
# 'pro:wh|what~cop|be&3S pro:dem|this n|+n|sweet+n|heart'
# 'co|hi'
# 'pro:dem|that~cop|be&3S adj|red'
# 'pro:wh|what aux|be&PRES det|those n|kitty-PL part|eat-PRESP co|sweetie'
# 'co|yeah conj|but pro:sub|I v|decide-PAST adv|maybe pro:sub|she mod|will&COND aux|be part|learn-PRESP inf|to v|use pro:obj|them adv|very adv|soon'
# 'pro:dem|these cop|be&PRES n|flower-PL'
# 'n|duck'
# 'art|the n|car mod|do&3S~neg|not v|have qn|any n|wheel-PL pro|it~aux|be&3S part|break&PASTP'
# 'pro:dem|that~cop|be&3S art|a n|house'
# 'pro:exist|here~cop|be&3S art|a n|white pro:indef|one'
# 'on|quack on|quack'
# 'co|yes pro:dem|that~cop|be&3S art|a n|house'
# 'v|put&ZERO art|the n|blanket prep|on art|the n|baby'
# 'pro:sub|she v|say&PAST n|blanket'
# 'n|blanket n|sweet&dadj-DIM'
# 'adj|good n|flower'
# 'n:prop|Daddy co|haha co|haha'
# 'BRK n|rabbit'
# 'n|bird-DIM'
# 'adv:wh|how v|do&3S art|the n|bird-DIM v|go'
# 'adv|actual&dadj-LY n:prop|Mommy pro|it~cop|be&3S art|a n|bear'
# 'co|yes'
# 'pro:wh|what n:prop|Mommy mod|do&3S n:prop|Nomi v|cast-3S adv|asunder'
# 'v|try pro|it n|honey on|heeheeheeheeheehee'
# 'pro:wh|what aux|be&PRES det|these n:prop|Nomi'
# 'co|yes n|slipper'
# 'v|go v|see n:prop|Daddy adj|okay n:prop|Naomi v|say pro:indef|something'
# 'pro:exist|there~cop|be&3S art|the n|fish'
# 'n:prop|Mama n|mouse'
# 'qn|no n|walrus n:prop|Naomi'
# 'v|brush art|the n|doll-DIM~poss|s n|hair n:prop|Nomi'
# 'adv|now adv|here'
# 'n:prop|Naomi'
# 'adv|pretty'
# 'on|peep on|peep on|peep'
# 'n|cheese'
# 'BRK n|baby'
# 'adv:wh|where~cop|be&3S art|the n|rabbit~poss|s n|hole'
# 'v|go prep|to art|the n|door n|honey'
# 'det|that n|dog-DIM~poss|s n|tail'
# 'co|no pro|it~cop|be&3S neg|not art|a n|dog-DIM'
# 'n|girl co|yes'
# 'co|honey pro:wh|what aux|be&PRES pro:dem|these'
# 'n|lie n|down adv|here n|sweet-PL'
# 'adv:wh|where~cop|be&3S art|a n|boat'
# 'chi|gogo'
# 'pro:wh|what~aux|be&3S art|the n|kitty part|eat-PRESP'
# 'n|hitch n|hitch'
# 'on|meow on|meow on|meow'
# 'n:prop|Goldie co|yeah'
# 'rel|whose rel|that adv|here'
# 'qn|another n|baby prep|in art|the n|boat'
# 'co|look co|look co|look pro:exist|there cop|be&3S art|a n|car'
# 'adv|here pro|it cop|be&3S n:prop|Nomi art|the n|book cop|be&3S prep|in pro:dem|here'
# 'EXC det:wh|what aux|be&PRES pro:sub|they'
# 'co|look'
# 'bab|maw'
# 'mod|do~neg|not v|draw prep|on art|the n|baby'
# 'art|a n|shoe'
# 'pro:wh|what cop|be&PAST&13S pro:dem|that'
# 'v|+n|night+v|night'
# 'n:prop|Daddy v|go v|see n:prop|Daddy'
# 'pro:exist|here~cop|be&3S art|the n|bird-DIM'
# 'pro:wh|what~aux|be&3S rel|that n:prop|Nomi'
# 'pro:wh|what aux|be&3S pro|it'
# 'v|get det|that n|ball'
# 'co|say meta|broken n:prop|Nomi'
# 'EXC EXC'
# 'pro:dem|that~cop|be&3S n|horse-DIM'
# 'pro:sub|she~cop|be&3S prep|over pro:dem|there pro:sub|she~cop|be&3S adv|there'
# 'n|brush n|baby~poss|s n|hair'
# 'n|pot-DIM n|pot-DIM v|say'
# 'co|night_night n:prop|Nomi'
# 'v|hit&ZERO'
# 'pro:dem|that~cop|be&3S adj|right pro|it v|go-3S adv|in adv|here n|+n|sweet+n|heart'
# 'co|oh pro|it~cop|be&3S art|a n|kitty'
# 'BRK BRK adj|wee'
# 'pro:dem|that~cop|be&3S art|a'
# 'n:prop|Nomi v|put&ZERO pro|it adv|in'
# 'n|night'
# 'n|horse neg|not art|a n|pig-DIM'
# 'adv:wh|how adj|big aux|be&3S n:prop|Nomi'
# 'v|say pro|it adv|again n|honey'
# 'qn|no co|no n|lie adv|down co|sweetheart n|lie adv|down'
# 'pro:exist|there cop|be&3S art|a n|car adv|out adv|there'
# 'pro|it~aux|be&3S part|get-PRESP adv|more coord|and adv|more adj|difficult aux|be&3S~neg|not pro|it n:prop|Nomi'
# 'chi|toydee n|toy'
# 'pro:dem|that~cop|be&3S art|a n|cow'
# 'EXC n:prop|Daddy'
# 'v|put&ZERO n|baby co|night_night n|honey'
# 'n|blanket'
# 'v|put&ZERO art|the n|blanket prep|on art|the n|baby n:prop|Nomi'
# 'BRK co|bye'
# 'pro|you'
# 'pro|you mod:aux|have_to v|get adj|big-CP n|ear-PL'
# 'part|break&PASTP part|break&PASTP'
# 'adv|there pro|you v|boogie'
# 'cop|be&3S rel|that art|a n|house'
# 'co|yeah pro:poss:det|its adj|good prep|for pro:poss:det|your part|dilate-PASTP n|pupil-PL'
# 'n|apple'
# 'pro:sub|I v|put&ZERO pro:dem|that prep|down art|the adj|wrong n|way'
# 'adv|now v|get art|the n|red det:num|one n:prop|Nomi'
# 'adv|over adv|there prep|by art|the n|bed'
# 'coord|and pro:wh|what cop|be&3S det|this art|a n|pig-DIM'
# 'co|okay adv|now v|say meta|blanket adv|again'
# 'co|oh EXC'
# 'co|no pro|you v|have pro|it'
# 'n|hat'
# 'co|oh rel|that n|baby co|yes pro|you v|get art|the n|baby'
# 'v|sit adv|down'
# 'co|yes n|boy'
# 'pro|you v|lie n|down coord|and v|close det|those n|eye-PL'
# 'v|show art|the n|dog-DIM'
# 'part|bark-PRESP'
# 'co|oh co|yes'
# 'pro:wh|what~cop|be&3S pro:dem|this n|honey'
# 'rel|whose pro:dem|that adv|in adv|there'
# 'n|turn'
# 'pro:sub|I mod|can v|put&ZERO art|a EXC adv|in adv|here adv|too adv|now pro:sub|I v|think'
# 'mod|do pro|you v|want prep|to n|beep'
# 'cop|be&1S pro:sub|I n|right'
# 'v|come prep|on n|sweet&dadj-DIM'
# 'cop|be&3S rel|that art|a n|toy'
# 'adv|here co|sweetie pro:exist|here~cop|be&3S art|a n|tissue prep|for pro|you'
# 'co|no co|say'
# 'cop|be&3S rel|that co|alright'
# 'n|duck v|say-3S on|quack'
# 'co|oh n|tissue pro|you v|want'
# 'co|yeah part|break&PASTP'
# 'adj|good pro|it~cop|be&3S n|flower'
# 'det|this adj|little n|pig-DIM v|go&PAST inf|to v|market'
# 'n|towel n|towel n|towel EXC'
# 'v|do&PAST pro|you v|leave art|the qn|other n|slipper adv|outside n:prop|Nomi'
# 'n|moon'
# 'n|diaper'
# 'pro:sub|I v|want inf|to v|hold pro|you prep|for art|a n|minute'
# 'v|go adv|away'
# 'pro:wh|what n|kind prep|of n|bird-DIM aux|be&3S pro|it'
# 'n|wagon'
# 'n|rock co|yes'
# 'co|right'
# 'v|bring art|the qn|other v|piece-3S n:prop|Nomi'
# 'v|peek pro|it'
# 'on|meow'
# 'adj|chic aux|be&3S rel|that art|a n|tree'
# 'co|hunm n|horse-DIM n|horse-DIM'
# Items in the second set but not the first:
# ''
# 'no|qn sweet|n you|pro just|adv go-PAST|v pot-DIM|n'
# 'owl|n'
# 'cam|chi'
# 'um|None um|None'
# 'that|pro be|cop a|det kitty|n huh|co'
# 'ball|n'
# 'maw|bab'
# 'they|pro they|pro do-PASTP|part'
# 'it|pro be|cop a|det horse|n'
# 'good|adj flower|n'
# 'these|pro be-PRES|cop flower-PL|n'
# 'peek|v it|pro'
# 'I|pro yyy|None'
# 'yes|co that|pro be|cop a|det house|n'
# 'pen|n'
# 'queen|n queen|n'
# 'yes|co boy|n'
# 'slipper|n slipper|n'
# 'yeah|co that|pro be|cop Contrary_Mary|n s|poss garden|n'
# 'okay|co'
# 'I|pro think|v Nomi|n be-3S|aux tire-PASTP|part'
# 'that|pro be|cop right|adj moo|on'
# 'stay|n in|prep here|adv Daddy|n be|aux go-PRESP|part to|inf bring|v the|det paper|n'
# 'want|v to|inf go|v see|v the|det snow|n'
# 'again|adv'
# 'it|pro do-3S|mod not|neg fit-ZERO|v'
# 'it|pro turn|v good|adj'
# 'there|pro be|cop the|det fish|n'
# 'this|pro be-3S|cop a|det big|adj shoe|n'
# 'yes|co Daddy|n'
# 'that|pro be|cop xxx|None slipper|n'
# 'mouse|n'
# 'put-ZERO|v Goldie|n through|prep the|det chimney|n'
# 'chick-DIM|n'
# 'oh|co the|det glass-PL|n be-PRES|aux break-PASTP|part'
# 'eh|None'
# 'you|pro have|v one|det two|det three|det'
# 'key|n'
# 'book|n'
# 'no|co'
# 'that|pro be-3S|cop where|pro the|det beautiful|adj princess|n live-3S|v Nomi|n'
# 'yes|co good|adj'
# 'boy|co'
# 'horse|n'
# 'be-3S|cop Nomi|n write-PRESP|part the|det dog|n s|poss tail|n'
# 'that|pro be|cop a|det walrus|n'
# 'cookie|n'
# 'petty|chi'
# 'Mommy|n'
# 'no|co no|co'
# 'pig-DIM|n right|adj'
# 'a|det Little_Miss_Muffet|n Little_Miss_Muffet|n sit-PAST|v on|prep her|det tuffet|n eat-PRESP|part her|det curd-PL|n and|coord whey|n along|adv come-PAST|v a|det'
# 'this|pro be-3S|cop the|det tongue|n Nomi|n'
# 'what|pro do-3S|v the|det chick-DIM|n say|co sweetie|co'
# 'mouse|n that|pro be|aux not|neg a|det mouse|n Nomi|n that|pro be|cop a|det house|n'
# 'whose|pro that|pro here|adv'
# 'pupil-PL|n what|pro s|poss a|det pupil|n'
# 'yes|co the|det baby|n be-3S|aux lie-PRESP|part down|adv'
# 'where|adv be|cop the|det rabbit|n'
# 'look|co'
# 'that|pro be|cop not|neg the|det moon|n'
# 'ear|n where|pro be|aux dog-DIM|n'
# 'you|pro'
# 'a|det book|n'
# 'go|v to|prep the|det door|n honey|n'
# 'pretty|adv big|adj'
# 'bark-PRESP|part'
# 'yes|co there|adv it|pro be-3S|cop'
# 'can|mod Nomi|n say|v'
# 'hat|None hat|n'
# 'where|adv be|cop a|det boat|n'
# 'chic|adj'
# 'xxx|None'
# 'where|adv be|cop the|det pig-DIM|n'
# 'see|v'
# 'we|pro have|v a|det disaster|n if|conj you|pro bang|v on|prep the|det glass|n'
# 'um|None what|pro be-PRES|aux those|pro'
# 'what|pro me|pro to|prep help|co'
# 'Nomi|n do|mod not|neg bang|v on|prep the|det glass|n'
# 'she|pro be|cop'
# 'what|pro be|cop this|pro Naomi|n who|pro be-3S|cop that|pro'
# 'eat|v'
# 'cow|n cow|n jump-PAST|v over|prep the|det moon|n read-ZERO|v Little_Miss_Muffet|n'
# 'say|v it|pro again|adv sweetie|co'
# 'oh|co a|det little|adj drawer|n'
# 'turn|n yes|co'
# 'slipper|n'
# 'oh|co that|pro baby|n yes|co you|pro get|v the|det baby|n'
# 'xxx|None yyy|None yyy|None'
# 'Daddy|None Daddy|n'
# 'this|pro be-3S|cop a|det slipper|n'
# 'be-3S|cop that|pro a|det toy|n'
# 'that|pro be|cop right|n'
# 'they|pro they|pro'
# 'truck|None truck|n'
# 'put-ZERO|v Goldie|n through|prep the|det chimney|n honey|n put-ZERO|v Goldie|n through|prep the|det chimney|n'
# 'Nomi|n lie|n down|adv too|post'
# 'Nomi|n this|pro be-3S|cop a|det vase|n'
# 'no|qn walrus|n Naomi|n'
# 'paper|n'
# 'there|pro be|cop the|det hat|n'
# 'bring|v the|det other|qn piece-PL|n Nomi|n'
# 'what|pro be|aux that|pro Naomi|n'
# 'yyy|None ah|co'
# 'that|pro be|cop a|det'
# 'see|v Mommy|n'
# 'night|n'
# 'huh|co'
# 'apple|n'
# 'you|pro can|mod see|v a|det car|n out|adv that|pro window|n'
# 'duck|None duck|n'
# 'gogo|chi'
# 'blue|adj'
# 'okay|co blanket|n'
# 'do|mod not|neg draw|v no|qn no|qn do|mod not|neg draw|v'
# 'eueueu|on'
# 'bam|chi'
# 'Mama|n mouse|n'
# 'she|pro go-PAST|v and|coord get-PAST|v the|det diaper|n after|prep say-PRESP|n dupper|meta or|coord what|pro ever|adv it|pro be-PAST|cop'
# 'this|pro be-3S|cop a|det nut|n'
# 'how|adv oh|co'
# 'what|pro be-PRES|aux those|pro kitty-PL|n eat-PRESP|part sweetie|co'
# 'okay|co sweetie|co let|v us|pro look|cop at|prep the|det book|n some|qn more|pro'
# 'good-CP|adv to|prep not|neg do|v it|pro on|prep the|det rug|n how|adv be|aux that|pro sweetie|co'
# 'who|pro be-3S|cop that|pro'
# 'go|v see|v Daddy|n okay|adj Naomi|n say|v something|pro'
# 'me|pro down|adv'
# 'house|n'
# 'uhhuh|co car|n'
# 'Daddy|n be|aux go-PRESP|part to|inf bring|v the|det paper|n honey|n'
# 'can|mod you|pro say|v'
# 'he|pro be-3S|aux go-PRESP|part to|prep turn|n off|prep the|det light-PL|n'
# 'honey|co what|pro be-PRES|aux these|pro'
# 'walrus|n'
# 'Flipper|n'
# 'dog-DIM|n yeah|co'
# 'another|qn baby|n in|prep the|det boat|n'
# 'okay|co say|co'
# 'that|pro be|cop a|det horse|n'
# 'well|co let|v us|pro have|v some|qn d|n i|n n|n n|n e|n r|n'
# 'shingle|n can|mod you|pro say|v'
# 'uhhuh|co say|v it|pro again|adv'
# 'up|adv'
# 'want|v to|inf put-ZERO|v the|det glass-PL|n on|adv'
# 'I|pro be|aux try-PRESP|part to|inf get|v word-PL|n with|prep b-PL|n and|coord p-PL|n now|adv'
# 'what|pro kind|n of|prep bird-DIM|n'
# 'okay|co come|v on|adv let-ZERO|v me|pro get|v you|pro xxx|None here|adv sweetie|co now|adv'
# 'do|mod you|pro put-ZERO|v this|pro on|prep the|det floor|n Nomi|n'
# 'remember|v we|pro see-PAST|v snow|n'
# 'Nomi|n where|adv be-3S|cop Mama|n mouse|n'
# 'she|pro be|aux over|adv there|adv she|pro be|cop there|adv'
# 'that|pro that|pro'
# 'no|co you|pro have|v it|pro'
# 'dangerous|adj Nomi|n'
# 'what|pro be|cop this|pro'
# 'yes|co what|pro be|aux the|det kitty|n in|prep here|adv'
# 'see|v the|det baby|n'
# 'break-PASTP|part'
# 'brush|v the|det doll-DIM|n s|poss hair|n Nomi|n'
# 'night_night|co sweetie|co'
# 'Nomi|n put-ZERO|v it|pro in|adv'
# 'what|pro be-PRES|aux these|pro thing-PL|n xxx|None fish|n'
# 'pig-DIM|n'
# 'be-1S|aux I|pro right|n'
# 'put-ZERO|v baby|n in|prep the|det boat|n'
# 'I|None think|None she|None has|None better|None Nomi|n say|v'
# 'byebye|co'
# 'how|adv big|adj be-3S|aux'
# 'ah|co'
# 'yyy|None no|co oh|co'
# 'what|pro be-PAST|cop that|pro'
# 'rabbit|n'
# 'at|prep the|det bottom|n Nomi|n'
# 'look|co look|co look|co there|adv be-3S|cop a|det car|n'
# 'diaper|n'
# 'kiss|n baby|n'
# 'be-PRES|cop you|pro ride-PRESP|part your|det gogo|chi'
# 'foot-DIM|n'
# 'whoops|co'
# 'woo|bab'
# 'book|n it|pro'
# 'hut|n'
# 'go|v night_night|co'
# 'yeah|co it|pro fit-3S|v'
# 'I|pro want|v to|inf hold|v you|pro for|prep a|det minute|n'
# 'there|adv be-3S|cop a|det car|n out|adv there|adv'
# 'bye|None bye|co'
# 'oug|on oug|on'
# 'that|pro be|cop right|adj bird-PL|n be-PRES|cop there|adv'
# 'that|pro be|cop a|det house|n'
# 'here|pro be|cop Goldie|n'
# 'good|adj it|pro be|cop flower|n'
# 'yes|co that|pro be-3S|cop what|pro the|det horse-DIM|n say-3S|v'
# 'there|pro be|cop the|det red|n one|pro'
# 'rock|n'
# 'windmill|n'
# 'ahhah|co baby|n and|coord there|pro be|cop a|det Mommy|n'
# 'what|pro be|aux that|pro Nomi|n'
# 'monkey|n'
# 'and|coord what|pro do-3S|v a|det chick-DIM|n say|v'
# 'yes|co slipper|n'
# 'it|pro be|cop a|det bird-DIM|n'
# 'boo|co'
# 'go|v wee|adj'
# 'sit|v down|adv brush|n hair|n'
# 'hat|n'
# 'box|n'
# 'you|pro lie|v down|adv and|coord close|v those|pro eye-PL|n'
# 'what|pro be-PRES|aux those|pro'
# 'ear|n'
# 'how|adv do-3S|v the|det bird-DIM|n go|v'
# 'night_night|co'
# 'toydee|chi toy|n'
# 'um|None kitty|n'
# 'green|adj light|n'
# 'towel|n towel|n towel|n yyy|None'
# 'baby|n duck|None duck|n'
# 'bite-PAST|v but|conj'
# u'up|None and|None up|adv and|coord up|adv'
# 'girl|n yes|co'
# 'egg-DIM|n'
# 'ba|bab'
# 'this|pro one|pro here|adv'
# 'okay|co okay|co here|pro be|cop the|det crayon|n'
# 'be-3S|aux it|pro a|det chicken|n'
# 'Nana|n'
# 'try|v it|pro honey|n heeheeheeheeheehee|on'
# 'where|adv'
# 'yes|co and|coord these|pro be-PRES|cop chick-DIM|n'
# 'yeah|co'
# 'yes|co that|pro be|cop right|n'
# 'Nomi|n what|pro be|cop this|pro'
# 'here|pro be|cop a|det boat|n'
# 'Naomi|n get-PAST|v up|adv already|adv'
# 'kitty-PL|n eat|v milk|n'
# 'be-3S|cop there|adv a|det mouse|n in|prep there|adv'
# 'that|pro be|cop red|adj'
# 'give|v me|pro a|det kiss|n and|coord I|pro will|mod get|v the|det xxx|None for|prep you|pro'
# 'Mommy|n a|det hug|n come|v give|v Mommy|n a|det hug|n'
# 'that|pro be|cop a|det cow|n'
# 'go|v to|prep the|det door|n in|prep the|det kitchen|n in|prep the|det kitchen|n honey|n'
# 'eh|None ah|None eh|None ah|co'
# 'Goldie|n'
# 'bird-DIM|n'
# 'oh|co yes|co'
# 'horse-DIM|n right|adv want|v to|inf build|v a|det tower|n'
# 'a|det house|n'
# 'payn|chi'
# 'uhhuh|co kitty|n'
# 'what|pro be|cop this|pro Nomi|n'
# 'who|pro'
# 'hunm|co horse-DIM|n horse-DIM|n'
# 'good|adj'
# 'oig|on ag|on oig|on oig|on oig|on oig|on'
# 'do|mod they|pro smell|v pretty|adv'
# 'you|pro lie|v down|adv too|adv with|prep the|det baby|n'
# 'that|pro be|cop your|det ear|n'
# 'do|mod not|neg you|pro draw|v on|prep the|det baby|n'
# 'you|pro still|adv do|mod not|neg have|v your|det slipper|n on|prep babe|n'
# 'dog-DIM|n'
# 'hm|co what|pro be|cop that|pro'
# 'yes|co Goldie|n write|v down|adv Goldie|n'
# u'how|adv house|None house|None house|n'
# 'whoops|co Goldie|n fall-PAST|v out|adv'
# 'oink|on oink|on here|pro be|cop a|det hat|n'
# 'what|pro be|aux be-3S|cop this|pro thing|n'
# 'woof|on woof|on woof|on'
# 'yes|co that|pro be-3S|cop Nomi|n in|prep the|det mirror|n'
# 'block|n'
# 'get|v that|pro that|pro ball|n'
# 'come|v on|prep what|pro be|aux that|pro Nomi|n'
# 'do|mod you|pro know|v what|pro any|qn of|prep those|pro be-PRES|cop'
# 'yes|co Mommy|n and|coord a|det Daddy|n'
# 'I|pro want|v you|pro to|inf be|aux cover-PASTP|part with|prep your|det blanket|n'
# 'be-3S|cop this|pro your|det slipper|n'
# u'mouse|None mouse|n'
# 'there|pro be|cop the|det bird-DIM|n'
# 'boot|n'
# 'no|co you|pro lie|v down|adv too|post'
# 'chicken|n'
# 'be|cop'
# 'yes|co that|pro be-3S|cop a|det house|n'
# 'down|adv'
# 'what|pro be-PRES|aux these|det Nomi|n'
# 'that|pro be|cop a|det city|n'
# 'ah|None ah|None ah|None ah|None ah|co'
# 'here|pro be|cop a|det mouse|n'
# 'chimney|n'
# 'look|cop at|prep the|det bottom|n'
# 'rabbit|None rabbit|n'
# 'whoo|co woo|v'
# 'where|adv be|cop the|det where|adv be|cop the|det hole|n Nomi|n'
# 'you|pro have_to|mod get|v big-CP|adj ear-PL|n'
# 'what|pro'
# 'what|pro be-PRES|aux you|pro do-PRESP|part Nomi|n'
# 'put-ZERO|v down|adv'
# u'house|None house|n'
# 'Nomi|n'
# 'there|adv you|pro boogie|v'
# 'if|conj you|pro want|v to|inf call|v it|pro that|pro it|pro be|cop fine|adj with|prep me|pro'
# 'do|mod not|neg draw|v on|prep the|det baby|n'
# 'it|pro be|cop money|n'
# 'yyy|None oig|on oig|on'
# 'here|adv'
# 'xxx|None baby|n'
# 'put-ZERO|v the|det blanket|n on|prep the|det baby|n'
# 'I|pro think|v Mama|n s|poss come-PRESP|part up|prep the|det stair-PL|n'
# 'oh|co you|pro want|v diaper|n Nomi|n'
# 'can|mod you|pro say|v pupil|meta Nomi|n'
# 'do|mod not|neg bang|v on|prep the|det glass|n'
# 'yyy|None hm|co'
# 'look|cop at|prep that|pro'
# 'get|v down|adv okay|adj'
# 'Naomi|n what|pro be|cop that|pro'
# 'tea|n in|prep the|det chimney|n'
# 'no|co say|co'
# 'what|pro Nomi|n'
# 'here|adv let|v us|pro put-ZERO|v it|pro like|v this|pro so|conj she|pro will|mod not|neg fall|v again|adv'
# 'show|v me|pro a|det tower|n show|v me|pro a|det tower|n tower|n'
# 'lie|v me|pro down|adv'
# 'hm|co'
# 'it|pro be|aux good-CP|adj to|inf build|v it|pro on|prep here|adv honey|n where|pro the|det floor|n be-3S|cop'
# 'what|pro do-3S|v the|det pig-DIM|n say|v'
# 'gaga|None gaga|bab'
# 'over|adv there|adv by|prep the|det bed|n'
# 'boo|bab'
# 'what|pro be-PAST|cop that|pro Naomi|n'
# 'no|qn ear|n Nomi|n'
# 'do|v'
# 'can|mod you|pro find|v some|qn bird-PL|n Nomi|n'
# 'show|v the|det dog-DIM|n'
# 'ah|co look|co Nomi|n a|det color-PRESP|part book|n'
# 'xxx|None yyy|None'
# 'want|v to|inf give|v Mommy|n a|det hug|n'
# 'hit-ZERO|v'
# 'can|mod she|pro reach|v this|pro'
# 'hi|co'
# 'but|conj do|mod not|neg use|v it|pro as|adv a|det dust|n cloth|n sweet|n'
# 'there|pro be|cop one|pro more|pro'
# 'what|pro be|cop this|pro honey|n'
# 'say|v it|pro again|adv honey|n'
# 'do-PAST|mod you|pro go|v to|prep the|det doctor|n today|adv'
# 'say|co slipper|meta Nomi|n'
# 'that|pro be|cop what|pro the|det pig-DIM|n say-3S|v oink|on oink|on yeah|co'
# 'come|v here|adv and|coord look|cop at|prep the|det book|n with|prep Mommy|n'
# 'what|pro be|cop that|pro honey|n'
# 'put-ZERO|v the|det coat|v over|adv here|adv'
# 'now|adv how|adv do|mod you|pro say|v'
# 'up|adv down|prep your|det dance-PRESP|part'
# 'whoo|co'
# 'duck|n'
# 'bird-DIM|n bird-DIM|n'
# 'night_night|co Nomi|n'
# 'poor|adj Goldie|n'
# 'woof|on woof|on'
# 'ahuhuhu|on'
# 'yes|co and|coord girl|n'
# 'here|adv it|pro be-3S|cop Nomi|n the|det book|n be-3S|cop in|prep here|adv'
# 'yes|co'
# 'okay|co pig-DIM|n'
# 'dog-DIM|n xxx|None'
# 'night_night|co Naomi|n'
# 'okay|co get|v the|det green|n one|det Nomi|n'
# 'the|det donkey|n be-3S|aux dance-PRESP|part dance-PRESP|part dance-PRESP|part'
# 'gun|n'
# 'be-3S|aux it|pro Goldie|n'
# 'blanket|n blanket|n'
# 'doll-DIM|n be|aux take-PRESP|part a|det nap|n'
# 'no|qn horse-DIM|n say-3S|v eheeheeheehee|on'
# 'okay|co say|v it|pro again|adv'
# 'what|pro be|aux the|det dog-DIM|n do-PRESP|part'
# 'mm|co'
# 'that|pro be|cop horse-DIM|n'
# 'quack|on quack|on'
# 'can|mod you|pro say|v that|pro'
# 'oh|co that|pro be-PAST|cop good|adj she|pro get-PAST|v all|adv'
# 'yes|co ah|co ah|co xxx|None pretty|adv huh|co'
# 'ah|co down|adv'
# 'milk|n kitty-PL|n eat|v cheese|n'
# 'what|pro be|cop this|pro sweet|n'
# 'what-PRES|pro what|pro be-PRES|aux you|pro do-PRESP|part'
# 'empty|adj'
# 'wait|v Nomi|n'
# 'let-ZERO|v me|pro see|v'
# 'table|n'
# 'Nomi|n need-3S|v big-CP|adj ear-PL|n'
# 'it|pro happen-3S|v to|inf be|cop the|det Chicago|n xxx|None or|coord something|pro that|pro be|aux a|det big|adj house|n'
# 'be-3S|cop the|det dog-DIM|n smell-PRESP|part'
# 'no|co it|pro be|cop not|neg a|det cow|n'
# 'how|adv big|adj be-3S|aux Nomi|n'
# 'how|adv'
# 'what|pro Mommy|n do-3S|mod Nomi|n cast-PL|n asunder|adv'
# 'sure|adj'
# 'how|adv be|aux that|pro tower|n'
# 'what|pro do-3S|v the|det dog-DIM|n say|v'
# 'lie|n down|adv here|adv sweet-PL|n'
# 'that|pro be|cop neat|adj that|pro you|pro turn|v it|pro and|coord it|pro let-3S|v it|pro go|v'
# 'right|co'
# 'that|pro be|cop your|det foot|n'
# 'that|pro be|cop a|det baby|n'
# 'up|adv pen|n'
# 'where|adv be|cop the|det bird-DIM|n'
# 'night_night|co sweet|n'
# 'meow|on meow|on meow|on'
# 'here|pro be|cop the|det moon|n'
# 'now|adv get|v the|det red|n one|det Nomi|n'
# 'the|det car|n do-3S|mod not|neg have|v any|qn wheel-PL|n it|pro be|aux break-PASTP|part'
# 'here|pro be|cop a|det kitty|n'
# 'shingle|n'
# 'ah|co oh|co baby|n'
# 'good|adj puppy|n'
# 'baby|n'
# 'okay|co now|adv say|v'
# 'duck|n say-3S|v quack|on'
# 'see|v at|prep the|det bottom|n you|pro can|mod see|v fish|n'
# 'house|n yes|co'
# 'hug|n'
# 'and|coord what|pro be-3S|cop this|pro a|det pig-DIM|n'
# 'oh|co slipper|n'
# 'yes|co yes|co good|adj girl|n'
# 'ah|co oh|co night_night|co'
# 'get|v down|adv'
# 'can|mod you|pro find|v a|det fish|n'
# 'no|qn the|det chick-DIM|n say-3S|v peep|on peep|on peep|on'
# 'eh|None ah|co'
# 'baby|None baby|n'
# 'that|pro be|cop the|det red|n one|pro'
# 'oh|co honey|n'
# 'chic|adj be-3S|aux that|pro a|det tree|n'
# 'say|co'
# 'okay|co now|adv say|v blanket|meta again|adv'
# 'there|pro be|cop Goldie|n again|adv'
# 'wagon|n'
# 'woo|None woo|bab'
# 'brush|n brush|n'
# 'whoops|co another|qn one|pro miss-PRESP|part'
# 'oig|None oig|on ye|bab'
# 'what|pro be-PRES|aux these|pro thing-PL|n in|prep here|adv Nomi|n'
# 'nothing|pro in|prep there|adv'
# 'car|n'
# 'eh|None ah|co ah|co oh|co'
# 'oh|co uh|None'
# 'do|mod you|pro want|v to|inf beep|v my|det nose|n'
# 'squirrel|n'
# 'what|pro be-PRES|aux these|pro sweet|n'
# 'I|pro will|mod bring|v the|det paper|n'
# 'break-PASTP|part break-PASTP|part'
# 'go|v find|v get|v the|det doll-DIM|n and|coord brush|v the|det doll-DIM|n s|poss hair|n'
# 'dance-PRESP|part'
# 'pillow|n'
# 'that|pro dog-DIM|n s|poss tail|n'
# 'good_night|co'
# 'the|det city|n of|prep Burning|n Towers|n'
# 'what|pro be|aux a|det pig-DIM|n say|v'
# 'here|pro be|cop another|qn horse|n Nomi|n'
# 'fall-PAST|v down|adv'
# 'spoon|n where|adv be|cop the|det spoon|n'
# 'there|adv she|pro go-3S|v'
# 'where|adv be|cop the|det house|n Naomi|n'
# 'sit|v down|adv'
# 'nut|n'
# 'flower|n'
# 'come|v on|adv here|pro be|cop a|det diaper|n in|prep here|adv Naomi|n'
# 'lala|bab'
# 'up|adv down|adv'
# 'wee|None wee|None wee|adj'
# 'I|pro put-ZERO|v that|pro down|prep the|det wrong|adj way|n'
# 'light-PL|n'
# 'a|det cow|n'
# 'this|pro little|adj pig-DIM|n go-PAST|v to|inf market|v'
# 'gala|bab'
# 'Daddy|n go|v see|v Daddy|n'
# 'cone|n'
# 'no|co I|pro do|mod not|neg think|v so|co'
# 'turn|n'
# 'yes|co and|coord here|adv be-3S|cop a|det kitty|n'
# 'come|v on|prep play|n with|prep the|det mouse|n house|n'
# 'leave|v it|pro over|adv here|adv while|conj we|pro be|aux not|neg use-PRESP|part it|pro'
# 'what|det do|v kitty-PL|n eat|v'
# 'oh|co oh|co look|cop at|prep it|pro spin|v'
# 'gaga|bab'
# 'uhhuh|co'
# 'yes|co snow|n at|prep the|det window|n huh|co'
# 'do-PAST|v you|pro leave|v the|det other|qn slipper|n outside|adv Nomi|n'
# 'yes|co that|pro be|cop a|det good|adj girl|n'
# 'Mammy|n'
# 'rock|n yes|co'
# 'will|mod you|pro come|v in|adv here|adv and|coord we|None will|None play|None with|None mouse|None we|pro will|mod play|v with|prep the|det mouse|n house|n'
# 'bacon|n'
# 'oh|co it|pro be|cop a|det kitty|n'
# 'tissue|n'
# 'tweet|on tweet|on'
# 'where|adv be|cop dog-DIM|n s|poss tail|n'
# 'flower-3S|v smell|n the|det flower-PL|n'
# 'they|pro be-PRES|aux call-PASTP|part glass-PL|n'
# 'cheese|n yeah|co'
# 'where|adv be|cop the|det rabbit|n s|poss hole|n'
# 'Jerry|n make-PAST|v that|pro'
# 'good|adj and|coord the|det bird-DIM|n say-3S|v'
# 'where|adv be|cop a|det fish|n Nomi|n'
# 'crane|n'
# 'he|pro a|det pot-DIM|n'
# 'come|v on|prep Naomi|n lie|n down|adv I|pro be|aux go-PRESP|part to|inf change|v your|det diaper|n hm|co'
# 'go|v in|prep the|det kitchen|n and|coord see|v Daddy|n'
# 'yyy|None me|pro up|adv'
# 'that|pro be|cop good|adj I|pro can|mod plug|v it|pro right|adv in|prep here|adv'
# 'yeah|co its|det good|adj for|prep your|det dilate-PASTP|part pupil-PL|n'
# 'that|pro be|cop dangerous|adj'
# 'here|pro be|cop the|det bird-DIM|n'
# 'mouse|n that|pro be|aux baby|n mouse|n Nomi|n'
# 'Dadda|n'
# 'moo|on'
# 'xxx|None do|mod you|pro want|v to|inf turn|v that|pro'
# 'see|co want|v me|pro to|inf wash|v your|det tooth-PL|n'
# 'ahhah|co and|coord a|det cow|n say-3S|v'
# 'come|v look|cop at|prep the|det picture|n of|prep the|det horse|n'
# 'oh|co do|mod they|pro smell|v nice|adj'
# 'it|pro fit-3S|v Nomi|n'
# 'okay|co pin|n'
# 'he|pro that|pro that|pro'
# 'like|conj Mommy|n have-3S|aux on|adv'
# ...
# 'kitty|n'
# 'I|pro will|mod get|v the|det other|qn slipper|n'
# 'where|adv be|cop the|det moon|n'
# 'a|det brush|n'
# 'do|mod you|pro have|v the|det slipper|n'
# 'put-ZERO|v baby|n night_night|co honey|n'
# 'brush|n baby|n s|poss hair|n'
# 'oig|on oig|on oig|on yyy|None'
# 'pin|n'
# 'kangaroo|n kangaroo|n'
# 'blanket|n'
# 'blanket|n sweetie|co'
# 'hutch|chi'
# 'doctor|n'
# 'xxx|None do|mod you|pro want|v to|inf smell|v the|det flower|n Nomi|n'
# 'me|pro down|adv up|adv'
# 'um|None yyy|None'
# 'car|None car|None car|n'
# 'uh|None'
# 'play|n with|prep the|det bird-DIM|n'
# 'what|pro xxx|None'
# 'xxx|None the|det little|adj drawer|n'
# 'be|aux bit|bab'
# 'who|pro be|aux that|pro sweetie|co'
# 'here|pro be|cop a|det white|n one|pro'
# 'look|co what|pro be-3S|cop here|adv sweetie|co'
# 'read-ZERO|v a|det book|n'
# 'there|pro be|cop the|det paper|n honey|n and|coord the|det book|n'
# 'no|co that|pro be|cop the|det blue|n one|pro'
# 'red|adj one|pro'
# 'no|co it|pro be|cop not|neg a|det dog-DIM|n'
# 'say|co broken|meta Nomi|n'
# 'fish|n'
# 'yes|co the|det water|n baby|n live-3S|v here|adv'
# 'Daddy|n haha|co haha|co'
# 'good|adj kiss|n'
# 'be-3S|cop that|pro alright|adj'
# 'meow|on'
# 'come|v on|prep gogo|chi'
#
# ======================================================================
# FAIL: test_word_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-18-7379067e0323>", line 15, in test_word_difference
#     self.assertEqual(set(words_db), set(words_nltk))
# AssertionError: Items in the first set but not the second:
# '&hmm'
# '&aw'
# '&eh'
# '0'
# '&ah'
# '&mm'
# '&um'
# '&uh'
# Items in the second set but not the first:
# 'um'
# 'eh'
# u'mm'
# u'ah'
# u'sipper'
# u'boydie'
# u'dat'
# u'hm'
# u'blankin'
# 'uh'
# 'aw'
# u'whatcha'
#
# ======================================================================
# FAIL: test_word_mor_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-18-7379067e0323>", line 23, in test_word_mor_difference
#     self.assertEqual(set(word_mors_db), set(word_mors_nltk))
# AssertionError: Items in the first set but not the second:
# 'adv|actual&dadj-LY'
# 'conj|so'
# 'n|key'
# 'v|tell'
# 'meta|pupil'
# 'conj|when'
# 'v|draw'
# 'adj|good'
# 'EXC'
# 'n:let|b-PL'
# 'n|picture'
# 'pro:indef|nothing'
# 'n|bacon'
# 'on|quack'
# 'adv|up'
# 'adv:wh|where'
# 'v|wash'
# 'cop|be&3S'
# 'n|box'
# 'n|boy'
# 'n|play'
# 'n|bottom'
# 'v|close'
# 'bab|woo'
# 'pro:obj|them'
# 'on|woof'
# 'n|lie-PL'
# 'n|crane'
# 'n|tongue'
# 'qn|some'
# 'v|do'
# 'n|coat'
# 'adv|now'
# 'prep|off'
# 'n|place'
# 'co|boo'
# 'co|knock'
# 'on|oug'
# 'pro:sub|I'
# 'n|chimney'
# 'adv|there'
# 'n|glass'
# 'co|boy'
# 'v|do&3S'
# 'n:prop|Mama~poss|s'
# 'chi|toydee'
# 'part|miss-PRESP'
# 'n|milk'
# 'n|green'
# 'part|come-PRESP'
# 'n|mouse'
# 'n|doctor'
# 'prep|up'
# 'n|egg-DIM-PL'
# 'n|chick-DIM-PL'
# 'aux|have&3S'
# 'n|white'
# 'det|that'
# 'n:prop|Mama'
# 'pro:exist|here'
# 'adj|big'
# 'bab|ye'
# 'aux|be'
# 'NO_UTT'
# 'n|brush'
# 'pro:poss:det|your'
# 'adv|still'
# 'n|light'
# 'bab|lala'
# 'bab|ba'
# 'cop|be&PRES'
# 'det:num|two'
# 'adj|dangerous'
# 'n|sweet-PL'
# 'adj|wrong'
# 'pro:wh|what~cop|be&3S'
# 'pro|it~cop|be&3S'
# 'n|button'
# 'co|careful'
# 'n|ear-PL'
# 'adj|first'
# 'n|light-PL'
# 'adv|already'
# 'pro:poss:det|my'
# 'adv|never'
# 'n|dog-DIM'
# 'adv|outside'
# 'det:num|one'
# 'co|uhhuh'
# 'n|red'
# 'n:prop|Jerry'
# 'co|right'
# 'pro:sub|he'
# 'v|reach'
# 'v|realize-3S'
# 'v|know'
# 'n|flower'
# 'prep|out_of'
# 'n:prop|Grandmother~poss|s'
# 'v|get'
# 'n|block'
# 'prep|on'
# 'part|get-PRESP'
# 'n|snow'
# 'n|way'
# 'n|cookie'
# 'pro:poss:det|its'
# 'prep|for'
# 'v|find'
# 'conj|while'
# 'n|minute'
# 'v|jump-PAST'
# 'pro:obj|me'
# 'adv:tem|today'
# 'n|dust'
# 'v|fit-3S'
# 'cop|be'
# 'n|ball'
# 'on|neheeheeheeheehee'
# 'n|cow'
# 'adv|nice&dadj-LY'
# 'v|like'
# 'pro:sub|we~cop|be&PRES'
# 'pro:sub|they'
# 'qn|no'
# 'n|rabbit~poss|s'
# 'adv|soon'
# 'n|bed'
# 'part|color-PRESP'
# 'n|sleep'
# 'co|help'
# 'co|sweetheart'
# 'n:prop|Little_Miss_Muffet'
# 'co|whoops'
# 'co|sweetie'
# 'conj|if'
# 'v|bring'
# 'on|meow'
# 'v|show'
# 'n|walrus'
# 'chi|payn'
# 'n:prop|Goldie'
# 'v|lie-3S'
# 'on|eueueu'
# 'n|pig-DIM'
# 'n|pen'
# 'prep|among'
# 'pro:dem|that'
# 'v|cast-3S'
# 'n|queen'
# 'n|eye'
# 'n|garden'
# 'adj|big-CP'
# 'n|curd-PL'
# 'n|lady'
# 'part|close-PASTP'
# 'v|say&PAST'
# 'n|nap'
# 'n|pot-DIM'
# 'adv:wh|how~aux|be&3S'
# 'meta|dupper'
# 'n|+n|sweet+n|heart'
# 'pro:wh|who'
# 'v|fit&ZERO'
# 'v|blow'
# 'adv|here'
# 'pro:poss:det|her'
# 'co|remember'
# 'n|down'
# 'n|floor'
# 'v|hold'
# 'conj|like'
# 'pro:sub|she~cop|be&3S'
# 'v|put&ZERO'
# 'co|so'
# 'meta|broken'
# 'v|sit'
# 'n:prop|Towers'
# 'n|sweet&dadj-DIM'
# 'co|haha'
# 'n|window'
# 'pro|you'
# 'mod|do~neg|not'
# 'bab|bim'
# 'adv|ever'
# 'co|ugh'
# 'n|house'
# 'on|moo'
# 'n|hug'
# 'rel|whose'
# 'n|glass-PL'
# 'pro:dem|here'
# 'n|kangaroo'
# 'n|hut'
# 'n|rabbit'
# 'n|windmill'
# 'v|look'
# 'det:num|three'
# 'n|tree'
# 'on|oink'
# 'n|tuffet'
# 'n|slipper'
# 'bab|doodie'
# 'n|kiss'
# 'on|eheeheeheehee'
# 'adv|along'
# 'mod|do&3S~neg|not'
# 'pro|it'
# 'n|tail'
# 'n|squirrel'
# 'n|toy'
# 'n:gerund|eat-PRESP'
# 'v|sit&PAST'
# 'chi|peggie'
# 'n:prop|Mammy'
# 'co|no'
# 'adv|all'
# 'part|lie-PRESP'
# 'v|try'
# 'aux|be&3S~neg|not'
# 'n|owl'
# 'v|say-3S'
# 'n|cone'
# 'n|whey'
# 'adv|ill'
# 'n|lie'
# 'pro|you~mod|will'
# 'prep|with'
# 'rel|who'
# 'aux|be&3S'
# 'n|kitty'
# 'n:prop|Nana'
# 'n|car'
# 'v|fall'
# 'adj|beautiful'
# 'n:let|p-PL'
# 'n|care-FUL'
# 'prep|of'
# 'adj|purple'
# 'n|flower-PL'
# 'adj|blue'
# 'v|go&PAST'
# 'co|ahhah'
# 'art|the'
# 'co|whoo'
# 'prep|to'
# 'mod|do'
# 'n|foot-DIM'
# 'part|brush-PRESP'
# 'n:prop|Daddy'
# 'adj|ease&dn-Y'
# 'n:let|r'
# 'pro:dem|those'
# 'n:let|n'
# 'n:let|i'
# 'n:let|d'
# 'n:let|e'
# 'n|horse-DIM'
# 'pro:sub|I~aux|be&1S'
# 'n:prop|Dadda'
# 'rel|that~aux|be&3S'
# 'n|monkey'
# 'bab|gaga'
# 'n|beep'
# 'adv|maybe'
# 'v|spin'
# 'v|peek'
# 'part|break&PASTP'
# 'v|fall&PAST'
# 'chi|hutch'
# 'on|ag'
# 'co|okay'
# 'adv|just'
# 'adv|out'
# 'v|lie'
# 'adv|away'
# 'v|turn'
# 'n|hair'
# 'co|yeah'
# 'n|drawer'
# 'pro:dem|there'
# 'art|a'
# 'mod|will&COND'
# 'on|ahu'
# 'adv|in'
# 'v|time'
# 'n|boat'
# 'adj|chic'
# 'adj|lay'
# 'n|pupil-PL'
# 'n|donkey'
# 'adv:wh|where~cop|be&3S'
# 'n|gun'
# 'det|this'
# 'prep|by'
# 'prep|over'
# 'qn|another'
# 'n:gerund|say-PRESP'
# 'n|doll-DIM~poss|s'
# 'n|word-PL'
# 'n:prop|Chicago'
# 'part|take-PRESP'
# 'n|mirror'
# 'n|thing-PL'
# 'n|stay'
# 'coord|and'
# 'n|ear'
# 'pro:wh|what'
# 'chi|petty'
# 'n|kitty-PL'
# 'bab|gala'
# 'v|hit&ZERO'
# 'pro:exist|there'
# 'n|tooth&PL'
# 'n:prop|Flipper'
# 'adj|wee'
# 'n|princess'
# 'co|good_night'
# 'n|home'
# 'n:prop|Mommy~poss|s'
# 'n:prop|Little_Red_Riding_Hood'
# 'v|build'
# 'v|live-3S'
# 'prep|after'
# 'n|pupil'
# 'n|blue'
# 'pro:indef|one'
# 'adj|sure'
# 'n:prop|Contrary_Mary~poss|s'
# 'adv|down'
# 'n|book'
# 'pro:wh|who~cop|be&3S'
# 'n|tea'
# 'co|whoopsie'
# 'n|boot'
# 'n|doll-DIM~aux|be&3S'
# 'adj|nice'
# 'n|rock'
# 'part|dilate-PASTP'
# 'n|paper'
# 'v|remember'
# 'n|bear'
# 'n|dog-DIM~poss|s'
# 'cop|be&1S'
# 'adj|neat'
# 'n|fall'
# 'adj|care&dn-FULL'
# 'adj|green'
# 'n|water'
# 'v|play'
# 'chi|cam'
# 'co|bye'
# 'pro:indef|more'
# 'det|these'
# 'n|chicken'
# 'n|city'
# 'n|chick-DIM'
# 'adj|pretty'
# 'v|let~pro:obj|us'
# 'v|write'
# 'co|well'
# 'adv|again'
# 'n|puppy'
# 'coord|or'
# 'pro:exist|here~cop|be&3S'
# 'v|brush'
# 'pro:dem|this'
# 'n|baby'
# 'n|arm'
# 'n|nut'
# 'v|piece-3S'
# 'part|call-PASTP'
# 'n:prop|Daddy~aux|be&3S'
# 'on|oig'
# 'on|ahuhuhu'
# 'v|eat'
# 'v|want'
# 'n|tower'
# 'n|rug'
# 'on|beep'
# 'n|towel'
# 'meta|slipper'
# 'pro:sub|she'
# 'v|make&PAST'
# 'n|shingle'
# 'n|push'
# 'n|spider'
# 'v|happen-3S'
# 'adv|more'
# 'n|honey'
# 'n|hat'
# 'chi|bam'
# 'chi|ban'
# 'pro:poss|mine'
# 'adj|okay'
# 'inf|to'
# 'adj|poor'
# 'co|honey'
# 'part|hit&PASTP'
# 'adv|asunder'
# 'pro:sub|we'
# 'v|say'
# 'v|get&PAST'
# 'n|money'
# 'mod|do&3S'
# 'co|night_night'
# 'adv|good&CP'
# 'on|heeheeheeheeheehee'
# 'n|horse'
# 'part|tire-PASTP'
# 'adv:wh|how'
# 'v|change'
# 'adv|right'
# 'pro:dem|these'
# 'adv|on'
# 'v|go'
# 'part|go-PRESP'
# 'v|lose'
# 'n|dog~poss|s'
# 'part|write-PRESP'
# 'part|cover-PASTP'
# 'v|let&ZERO'
# 'n|girl'
# 'mod:aux|have_to'
# 'v|beep'
# 'n|bun'
# 'v|wait'
# 'v|call'
# 'mod|will~neg|not'
# 'co|oh'
# 'n|kind'
# 'co|byebye'
# 'n|vase'
# 'part|try-PRESP'
# 'co|ow'
# 'prep|at'
# 'n|tissue'
# 'n|bird-PL'
# 'adj|kit&dn-Y'
# 'adv|very'
# 'part|eat-PRESP'
# 'adv|as'
# 'conj|but'
# 'meta|blanket'
# 'n|pin'
# 'n|fish'
# 'part|use-PRESP'
# 'mod|will'
# 'n|table'
# 'n|pillow'
# 'prep|in'
# 'post|too'
# 'n:prop|Nomi'
# 'n|kitchen'
# 'n|cloth'
# 'n|hole'
# 'bab|ca'
# 'n|foot'
# 'n|thing'
# 'n:prop|Mama~aux|be&3S'
# 'pro:dem|that~aux|be&3S'
# 'v|bite&PAST'
# 'n|knock'
# 'neg|not'
# 'on|gu'
# 'n|door'
# 'n|disaster'
# 'part|do-PRESP'
# 'on|peep'
# 'n|noon'
# 'det:wh|what'
# 'part|stick-PRESP'
# 'co|say'
# 'adj|difficult'
# 'n|wheel-PL'
# 'pro|it~aux|be&3S'
# 'v|use'
# 'v|smell'
# 'n:prop|Mommy'
# 'n|babe'
# 'co|hunm'
# 'pro:sub|I~mod|will'
# 'mod|can'
# 'v|see'
# 'v|bang'
# 'v|come'
# 'co|hi'
# 'v|woo'
# 'pro:indef|something'
# 'v|boogie'
# 'aux|be&PRES'
# 'n|duck'
# 'v|read&ZERO'
# 'cop|be&PAST&13S'
# 'n|eye-PL'
# 'part|smell-PRESP'
# 'n|bird-DIM'
# 'n|spoon'
# 'v|go-3S'
# 'co|yes'
# 'v|see&PAST'
# 'cop|be&PAST'
# 'n|right'
# 'adj|bottom'
# 'n:prop|Naomi'
# 'adv|pretty'
# 'n|cheese'
# 'adj|good&CP'
# 'pro:wh|what~poss|s'
# 'adj|little'
# 'v|need-3S'
# 'chi|gogo'
# 'qn|any'
# 'pro:wh|what~aux|be&3S'
# 'part|learn-PRESP'
# 'det|those'
# 'n|crayon'
# 'n|doll-DIM'
# 'n|piece'
# 'co|look'
# 'n|truck'
# 'bab|maw'
# 'n|baby~poss|s'
# 'n|stair-PL'
# 'rel|where'
# 'v|+n|night+v|night'
# 'bab|boo'
# 'v|leave'
# 'bab|bit'
# 'pro:sub|we~mod|will'
# 'rel|that'
# 'prep|through'
# 'n:prop|Burning'
# 'pro:dem|that~cop|be&3S'
# 'v|market'
# 'v|think'
# 'co|see'
# 'n|night'
# 'qn|other'
# 'n|nose'
# 'v|think&PAST'
# 'adj|fine'
# 'prep|down'
# 'adv|over'
# 'pro:exist|there~cop|be&3S'
# 'v|feel'
# 'n|blanket'
# 'v|plug'
# 'BRK'
# 'n|shoe'
# 'n|apple'
# 'part|do&PASTP'
# 'adv|too'
# 'co|alright'
# 'on|tweet'
# 'v|let-3S'
# 'part|dance-PRESP'
# 'adj|empty'
# 'v|stay'
# 'part|bark-PRESP'
# 'v|come&PAST'
# 'n|turn'
# 'n|lot'
# 'adj|red'
# 'v|decide-PAST'
# 'n|head'
# 'n|moon'
# 'aux|be-PRESP'
# 'n|diaper'
# 'v|have'
# 'part|ride-PRESP'
# 'n|hitch'
# 'n|wagon'
# 'adj|right'
# 'v|give'
# 'co|huh'
# 'v|do&PAST'
# 'part|say-PRESP'
# Items in the second set but not the first:
# 'Contrary_Mary|n'
# 'take-PRESP|part'
# 'owl|n'
# 'this|pro'
# 'cam|chi'
# 'ball|n'
# 'maw|bab'
# 'hit-PASTP|part'
# 'try|v'
# 'today|adv'
# 'pen|n'
# 'spin|v'
# 'okay|co'
# 'have|v'
# 'now|adv'
# 'okay|adj'
# 'do|mod'
# 'i|n'
# 'again|adv'
# 'light|n'
# 'sweetie|co'
# 'go-PRESP|part'
# 'pupil-PL|n'
# 'mouse|n'
# 'there|adv'
# 'get|v'
# 'eh|None'
# 'monkey|n'
# 'key|n'
# 'book|n'
# 'no|co'
# 'ugh|co'
# 'boy|co'
# 'down|prep'
# 'horse|n'
# 'will|mod'
# 'flower-3S|v'
# 'cookie|n'
# 'petty|chi'
# 'Mommy|n'
# 'sweet-PL|n'
# 'what-PRES|pro'
# 'look|cop'
# 'thing|n'
# 'ease-dn|adj'
# 'boo|bab'
# 'look|co'
# 'cast-PL|n'
# 'ag|on'
# 'knock|n'
# 'd|n'
# 'very|adv'
# 'bark-PRESP|part'
# 'more|adv'
# 'there|pro'
# 'kitty-PL|n'
# 'chic|adj'
# 'give|v'
# 'xxx|None'
# 'oink|on'
# 'see|v'
# 'tire-PASTP|part'
# 'on|adv'
# 'big|adj'
# 'say|co'
# 'dey|None'
# 'do-3S|mod'
# 'slipper|n'
# 'think|v'
# 'n|n'
# 'dupper|meta'
# 'say-PRESP|n'
# 'gala|bab'
# 'doll-DIM|n'
# 'bacon|n'
# 'curd-PL|n'
# 'market|v'
# 'go|v'
# 'boy|n'
# 'or|coord'
# 'find|v'
# 'be-1S|aux'
# 'nice-dadj|adv'
# 'night|v'
# 'her|pro'
# 'see-PAST|v'
# 'night|n'
# 'leave|v'
# 'huh|co'
# 'apple|n'
# 'honey|n'
# 'where|pro'
# 'gogo|chi'
# 'nap|n'
# 'blue|adj'
# 'she|None'
# 'miss-PRESP|part'
# 'eueueu|on'
# 'bam|chi'
# 'lady|n'
# 'build|v'
# 'big-CP|adj'
# 'stair-PL|n'
# 'bring|v'
# 'whoopsie|co'
# 'mm|co'
# 'write-PRESP|part'
# 'your|det'
# 'hitch|n'
# 'walrus|n'
# 'city|n'
# 'ride-PRESP|part'
# 'woo|None'
# 'never|adv'
# 'boot|n'
# 'come-PAST|v'
# 'after|prep'
# 'head|n'
# 'up|adv'
# 'home|n'
# 'smell|n'
# 'but|conj'
# 'you|pro'
# 'if|conj'
# 'smell|v'
# 'bit|bab'
# 'ban|chi'
# 'think-PAST|v'
# 'lay|v'
# 'how|None'
# 'honey|co'
# 'break-PASTP|part'
# 'ye|bab'
# 'pig-DIM|n'
# 'ah|co'
# 'when|conj'
# 'some|qn'
# 'tell|v'
# 'red|adj'
# 'rabbit|n'
# u'and|None'
# 'one|det'
# 'dangerous|adj'
# 'foot-DIM|n'
# 'gaga|None'
# 'be-3S|cop'
# 'pupil|meta'
# 'play|n'
# 'hut|n'
# 'glass|n'
# 'whose|pro'
# 'spider|n'
# 'play|v'
# 'so|co'
# 'rock|n'
# 'windmill|n'
# 'boogie|v'
# 'what|det'
# 'smell-PRESP|part'
# 'box|n'
# u'pretty|None'
# 'along|adv'
# 'boo|co'
# 'in|adv'
# 'hat|n'
# 'ear|n'
# 'night_night|co'
# 'oug|on'
# 'toy|n'
# 'to|inf'
# 'place|n'
# 'that|pro'
# 'door|n'
# 'Nana|n'
# 'Grandmother|n'
# 'where|adv'
# 'yeah|co'
# 'white|n'
# 'heeheeheeheeheehee|on'
# 'do-3S|v'
# 'not|neg'
# 'piece|n'
# 'put-ZERO|v'
# 'fall-PAST|v'
# 'Goldie|n'
# 'bird-DIM|n'
# 'whey|n'
# 'like|conj'
# 'payn|chi'
# 'already|adv'
# 'who|pro'
# 'good|adj'
# 'Jerry|n'
# 'one|pro'
# 'toydee|chi'
# 'another|qn'
# 'call|v'
# 'say|v'
# 'wait|v'
# 'dog-DIM|n'
# 'woof|on'
# 'so|conj'
# 'button|n'
# 'duck|None'
# 'paper|n'
# 'Flipper|n'
# 'fine|adj'
# 'say-PRESP|part'
# 'bye|None'
# 'house|None'
# 'chicken|n'
# 'be|cop'
# 'peek|v'
# 'down|adv'
# 'big|None'
# 'p-PL|n'
# 'tail|n'
# 'happen-3S|v'
# 'I|None'
# 'wee|None'
# 'ah|None'
# 'chimney|n'
# 'green|adj'
# 'Towers|n'
# 'what|pro'
# 'Nomi|n'
# 'bite-PAST|v'
# 'be-3S|aux'
# 'my|det'
# 'up|prep'
# 'here|adv'
# 'know|v'
# 'eye-PL|n'
# 'rabbit|None'
# 'minute|n'
# 'by|prep'
# 'eheeheeheehee|on'
# 'eat|v'
# 'of|prep'
# 'dog|n'
# 'drawer|n'
# 'Daddy|None'
# 'hm|co'
# 'write|v'
# 'eat-PRESP|part'
# 'those|pro'
# 'still|adv'
# 'ear-PL|n'
# 'do|v'
# 'these|pro'
# 'feel|v'
# 'Little_Red_Riding_Hood|n'
# 'hit-ZERO|v'
# 'hi|co'
# 'aw|None'
# 'hunm|co'
# 'sleep|n'
# 'red|n'
# 'b-PL|n'
# 'hat|None'
# 'arm|n'
# 'I|pro'
# 'time|v'
# 'right|n'
# 'we|None'
# 'duck|n'
# 'come|v'
# 'go-3S|v'
# 'ahuhuhu|on'
# 'kitchen|n'
# 'color-PRESP|part'
# 'see|co'
# 'alright|co'
# 'window|n'
# 'gun|n'
# 'Chicago|n'
# 'Little_Miss_Muffet|n'
# 'too|adv'
# 'blue|n'
# 'lie|n'
# 's|poss'
# 'call-PASTP|part'
# 'a|None'
# 'kiss|n'
# 'blanket|meta'
# 'play|None'
# 'realize-3S|v'
# 'thing-PL|n'
# 'empty|adj'
# 'bird-PL|n'
# 'lie-PRESP|part'
# 'to|prep'
# 'table|n'
# 'donkey|n'
# 'how|adv'
# 'sure|adj'
# 'knock|co'
# 'the|det'
# 'Daddy|n'
# 'rug|n'
# 'beautiful|adj'
# 'away|adv'
# 'among|prep'
# 'shingle|n'
# 'poor|adj'
# 'baby|v'
# 'he|pro'
# 'car|None'
# 'read-ZERO|v'
# 'baby|n'
# 'use-PRESP|part'
# 'green|n'
# 'hug|n'
# 'water|n'
# 'bottom|n'
# 'her|det'
# 'other|qn'
# 'oh|co'
# 'e|n'
# 'truck|None'
# u'mouse|None'
# 'actual-dadj|adv'
# 'be-PRESP|aux'
# 'lot|n'
# 'be|aux'
# 'fit-ZERO|v'
# 'it|pro'
# 'wagon|n'
# 'flower-PL|n'
# 'will-COND|mod'
# 'with|prep'
# 'car|n'
# 'squirrel|n'
# 'soon|adv'
# 'crayon|n'
# 'dance-PRESP|part'
# 'pillow|n'
# 'way|n'
# 'sit|v'
# 'good_night|co'
# 'dust|n'
# 'dilate-PASTP|part'
# 'bed|n'
# 'nut|n'
# 'flower|n'
# 'bottom|adj'
# 'get-PAST|v'
# 'lala|bab'
# 'hair|n'
# 'light-PL|n'
# 'Burning|n'
# 'tongue|n'
# 'ow|co'
# 'block|n'
# 'cone|n'
# 'noon|n'
# 'at|prep'
# 'uhhuh|co'
# 'want|v'
# 'a|det'
# 'tuffet|n'
# 'any|qn'
# 'for|prep'
# 'do-PASTP|part'
# 'alright|adj'
# 'wee|adj'
# 'say-PAST|v'
# 'tissue|n'
# 'as|adv'
# 'say-3S|v'
# 'have-3S|aux'
# 'and|coord'
# 'blow|v'
# 'outside|adv'
# 'crane|n'
# 'foot|n'
# 'tweet|on'
# 'two|det'
# 'broken|meta'
# 'hole|n'
# 'sweet|n'
# 'Dadda|n'
# 'moo|on'
# 'queen|n'
# 'like|v'
# 'word-PL|n'
# 'do-PAST|mod'
# 'towel|n'
# 'gu|on'
# 'stay|n'
# 'be-PRES|aux'
# 'do-PRESP|part'
# 'ca|bab'
# 'live-3S|v'
# 'more|pro'
# 'bear|n'
# 'have_to|mod'
# 'slipper|meta'
# 'yyy|None'
# 'over|prep'
# 'tree|n'
# 'ahu|on'
# 'me|pro'
# 'help|co'
# 'them|pro'
# 'careful|co'
# 'baby|None'
# 'puppy|n'
# 'too|post'
# 'in|prep'
# 'peep|on'
# 'disaster|n'
# 'first|adj'
# 'pretty|adj'
# 'nothing|pro'
# 'she|pro'
# 'tea|n'
# 'pretty|adv'
# 'little|adj'
# 'all|adv'
# 'diaper|n'
# 'floor|n'
# 'picture|n'
# 'push|n'
# 'need-3S|v'
# 'draw|v'
# 'snow|n'
# 'boat|n'
# 'bun|n'
# 'spoon|n'
# 'horse-DIM|n'
# 'haha|co'
# 'us|pro'
# 'bang|v'
# 'mirror|n'
# 'bim|bab'
# 'remember|co'
# 'r|n'
# 'egg-DIM|n'
# 'ba|bab'
# 'lose|v'
# 'well|co'
# 'learn-PRESP|part'
# 'purple|adj'
# 'babe|n'
# 'let-ZERO|v'
# 'tooth-PL|n'
# 'up|None'
# 'brush-PRESP|part'
# 'woo|v'
# 'pot-DIM|n'
# 'let-3S|v'
# 'maybe|adv'
# 'beep|on'
# 'sit-PAST|v'
# 'good-CP|adj'
# 'right|adj'
# 'mine|pro'
# 'we|pro'
# 'will|None'
# 'difficult|adj'
# 'something|pro'
# 'cheese|n'
# 'money|n'
# 'yes|co'
# 'through|prep'
# 'tower|n'
# 'ever|adv'
# 'princess|n'
# 'eye|n'
# 'gaga|bab'
# 'jump-PAST|v'
# 'out|adv'
# 'good-CP|adv'
# 'nice|adj'
# 'kind|n'
# 'come-PRESP|part'
# 'asunder|adv'
# 'wrong|adj'
# 'pupil|n'
# 'brush|v'
# 'over|adv'
# 'girl|n'
# 'make-PAST|v'
# 'on|prep'
# 'neat|adj'
# 'quack|on'
# 'wheel-PL|n'
# 'ahhah|co'
# 'cover-PASTP|part'
# 'close-PASTP|part'
# 'these|det'
# 'chick-DIM|n'
# 'wash|v'
# 'vase|n'
# 'oig|on'
# 'its|det'
# 'beep|n'
# 'kangaroo|n'
# 'piece-PL|n'
# 'off|prep'
# 'milk|n'
# 'beep|v'
# 'try-PRESP|part'
# 'house|n'
# 'has|None'
# 'fall|n'
# 'better|None'
# 'Naomi|n'
# 'byebye|co'
# 'do-PAST|v'
# 'fit-3S|v'
# 'stick-PRESP|part'
# 'can|mod'
# 'fall|v'
# 'reach|v'
# 'cow|n'
# 'decide-PAST|v'
# 'moon|n'
# 'go-PAST|v'
# 'three|det'
# 'doodie|bab'
# 'use|v'
# 'show|v'
# 'no|qn'
# 'coat|v'
# 'get-PRESP|part'
# 'remember|v'
# 'brush|n'
# 'hold|v'
# 'um|None'
# 'right|co'
# 'glass-PL|n'
# 'while|conj'
# 'neheeheeheeheehee|on'
# 'truck|n'
# 'bye|co'
# 'Mammy|n'
# 'here|pro'
# 'garden|n'
# 'out_of|prep'
# 'peggie|chi'
# 'turn|n'
# 'shoe|n'
# 'close|v'
# 'Mama|n'
# 'let|v'
# 'with|None'
# 'ill|adv'
# 'turn|v'
# 'kitty|n'
# 'lie-PL|n'
# 'think|None'
# 'change|v'
# 'just|adv'
# 'oig|None'
# 'plug|v'
# 'pin|n'
# 'blanket|n'
# 'hutch|chi'
# 'doctor|n'
# 'lie|v'
# 'uh|None'
# 'they|pro'
# 'whoo|co'
# 'right|adv'
# 'woo|bab'
# 'nose|n'
# 'cloth|n'
# 'fish|n'
# 'whoops|co'
# 'be-PAST|cop'
# 'be-PRES|cop'
# 'meow|on'
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.601s
#
# FAILED (failures=4)
# <unittest.runner.TextTestResult run=4 errors=0 failures=4>
