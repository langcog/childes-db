# %% [markdown]
# Import required packages

# %%
import unittest, config, MySQLdb, pandas, warnings, numpy, nltk
from childes import CHILDESCorpusReader # import from nltk.corpus.reader for original

# %% [markdown]
# Connect to DB

# %%
chompsky_authenticator = config.Authenticator('Chompsky')
chompsky_con= MySQLdb.connect(host=chompsky_authenticator.host, 
                port=chompsky_authenticator.port,user=chompsky_authenticator.user, passwd=chompsky_authenticator.passwd, 
                db='childes')

# %% [markdown]
# Configure corpus & files to test

# %%
region = 'Eng-NA' # or Eng-UK
corpus_name = 'Sachs'
fileid_name = 'n02'

# %% [markdown]
# Set up corpus information

# %%
corpus_root = '/home/alsan/corpora/childes-xml/%s' % region
corpus = CHILDESCorpusReader(corpus_root, '%s/.*.xml' % corpus_name)
fileid = ['%s/%s.xml' % (corpus_name, fileid_name)]
filename = '/shared_hd0/corpora/childes_new/%s/n02.cha' % corpus_name

# %% [markdown]
# Test if words / sentences / mors in CHILDES-DB are equal to those outputted by NLTK reader

# %%
class NLTKTest(unittest.TestCase):
    
    def setUp(self):
        sql_words = " SELECT gloss, mor FROM words \
                      WHERE filename = %(filename)s "
        sql_sents = " SELECT DISTINCT sentgloss, sentmor FROM words \
                      WHERE filename = %(filename)s "
        
        self.words_df = pandas.read_sql(sql_words, chompsky_con, params={'filename':filename})
        self.sents_df = pandas.read_sql(sql_sents, chompsky_con, params={'filename':filename})
        
    def test_word_difference(self):
        words_db = self.words_df['gloss'].values.T.tolist()
        
        words_nltk = corpus.words(fileid)
                
        self.assertEqual(set(words_db), set(words_nltk))
            
    def test_word_mor_difference(self):
        word_mors_db = self.words_df['mor'].values.T.tolist()
        
        tagged_words_nltk = corpus.tagged_words(fileid, stem=True)
        word_mors_nltk = ['%s|%s' % (p[1],p[0]) for p in tagged_words_nltk]
        
        self.assertEqual(set(word_mors_db), set(word_mors_nltk))
        
    def test_sent_difference(self):
        sents_db = self.sents_df['sentgloss'].values.T.tolist()
        
        sents_nltk = [" ".join(sent_arr) for sent_arr in corpus.sents(fileid)]
        
        self.assertEqual(set(sents_db), set(sents_nltk))
        
    def test_sent_mor_difference(self):
        sent_mors_db = self.sents_df['sentmor'].values.T.tolist()
        
        tagged_sents_nltk = corpus.tagged_sents(fileid, stem=True)
        sent_mors_nltk = [" ".join( ['%s|%s' % (p[1],p[0]) for p in arr] ) for arr in tagged_sents_nltk]
        
        self.assertEqual(set(sent_mors_db), set(sent_mors_nltk))
        
def suite():
    test_suite = unittest.TestSuite()
    test_suite.addTest(unittest.makeSuite(NLTKTest))
    return test_suite

# %% [markdown]
# Run test suite

# %%
test_suite = suite()
runner=unittest.TextTestRunner()
runner.run(test_suite)
# Out:
# FFFF
# ======================================================================
# FAIL: test_sent_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-20-64b1fc4815b7>", line 30, in test_sent_difference
#     self.assertEqual(set(sents_db), set(sents_nltk))
# AssertionError: Items in the first set but not the second:
# 'yes &ah &ah xxx pretty huh'
# 'they done'
# 'yyy &ah'
# '&um what are they'
# '&uh &uh yyy'
# '&ah'
# 'oh &uh ugh'
# "come on Naomi lie down I'm going to change your diaper &hmm"
# '&ah look Nomi a coloring book'
# '&um what are those'
# "&hmm what's that"
# '&eh &ah &ah oh'
# '&eh &ah'
# 'that'
# '&um yyy'
# '0'
# 'get that ball'
# '&um kitty'
# '&ah down'
# '&uh'
# '&hmm'
# '&um &um'
# 'what are you doing'
# 'oh &uh'
# 'they'
# '&ah oh baby'
# '&ah &ah &ah &ah &ah'
# 'yyy &hmm'
# 'he that'
# '&eh'
# '&eh &ah &eh &ah'
# '&mm'
# '&ah oh night_night'
# '&um'
# "&aw that's the easy way"
# Items in the second set but not the first:
# ''
# u'ah down'
# 'eh'
# u'um kitty'
# u'oh uh ugh'
# u'boydie birdie'
# u'eh ah'
# 'um'
# u'eh ah eh ah'
# u'sipper slipper'
# u'eh ah ah oh'
# u'ah look Nomi a coloring book'
# u'ah'
# u'yyy ah'
# u'he dat that'
# u'yyy hm'
# 'um yyy'
# u"come on Naomi lie down I'm going to change your diaper hm"
# u"hm what's that"
# u'ah ah ah ah ah'
# u'hm'
# u'um what are they'
# u'oh uh'
# u'ah oh night_night'
# u'yes ah ah xxx pretty huh'
# u'dat that'
# u'mm'
# u'dey dey they done'
# 'uh uh yyy'
# 'um um'
# u'dey they'
# u'um what are those'
# u'whatcha what are you doing'
# 'uh'
# u'get dat that ball'
# u"aw that's the easy way"
# u'ah oh baby'
# u'blankin blanket'
#
# ======================================================================
# FAIL: test_sent_mor_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-20-64b1fc4815b7>", line 38, in test_sent_mor_difference
#     self.assertEqual(set(sent_mors_db), set(sent_mors_nltk))
# AssertionError: Items in the first set but not the second:
# 'v|look prep|at art|the n|bottom'
# 'n:prop|Goldie adv|just mod|do&3S~neg|not v|want inf|to v|sit adv|in adv|there v|do&3S pro:sub|she'
# 'pro:dem|this cop|be&3S art|a n|windmill'
# 'co|whoopsie pro:exist|here~cop|be&3S art|a n|tissue prep|for pro|you'
# 'v|come adv|here coord|and v|look prep|at art|the n|book prep|with n:prop|Mommy'
# 'BRK n:prop|Daddy'
# 'rel|that art|a n|girl'
# 'adj|good coord|and art|the n|bird-DIM v|say-3S'
# 'n|mouse rel|that~aux|be&3S n|baby n|mouse n:prop|Nomi'
# 'pro:wh|what~aux|be&3S art|the n|kitty part|eat-PRESP'
# 'adv:wh|where~cop|be&3S art|the n|moon'
# 'co|yes art|the n|baby aux|be&3S part|lie-PRESP n|down'
# 'adv:wh|where'
# 'BRK n|mouse'
# 'pro:wh|what~cop|be&3S pro:dem|that n|honey'
# 'v|get art|the n|red pro:indef|one'
# 'adv:wh|how BRK BRK n|house'
# 'pro:dem|that~cop|be&3S adj|neat co|huh'
# 'pro:exist|here~cop|be&3S art|a n|boat'
# 'conj|but mod|do~neg|not v|use pro|it adv|as art|a n|dust n|cloth n|+n|sweet+n|heart'
# 'adv|good&CP prep|to neg|not v|do pro|it prep|on art|the n|rug adv:wh|how~aux|be&3S det|that n|sweet&dadj-DIM'
# 'pro:sub|they mod|will~neg|not v|stay prep|on pro:poss:det|your n|ear-PL n:prop|Nomi'
# 'pro:dem|that~cop|be&3S adj|good pro:sub|I mod|can v|plug pro|it adv|right prep|in pro:dem|here'
# 'art|a n|ball'
# 'n:prop|Nomi v|come adv|on v|look prep|at art|the n|book v|look prep|at art|the n|book'
# 'n|down'
# 'adv|there pro:sub|she v|go-3S'
# 'v|come adv|on pro:exist|here~cop|be&3S art|a n|diaper prep|in pro:dem|here n:prop|Naomi'
# 'EXC co|no co|oh'
# 'adv:wh|where~cop|be&3S art|the n|house n:prop|Naomi'
# 'v|see prep|at art|the n|bottom pro|you mod|can v|see n|fish'
# 'v|want inf|to v|put&ZERO art|the n|glass-PL adv|on'
# 'n|tree EXC n:prop|Daddy'
# 'pro:exist|here~cop|be&3S art|the n|moon'
# 'mod|can pro|you v|find art|a n|fish'
# 'on|oink on|oink pro:exist|here~cop|be&3S art|a n|hat'
# 'pro:wh|what cop|be&3S det|this n|honey'
# 'aux|be&3S pro|it art|a n|blanket'
# 'mod|do~neg|not pro|you v|draw prep|on art|the n|baby'
# 'n:prop|Nomi pro:wh|what~cop|be&3S pro:dem|this'
# 'co|okay v|get art|the n|green det:num|one n:prop|Nomi'
# 'n|egg-DIM-PL'
# 'EXC co|oh co|night_night'
# 'v|put&ZERO n:prop|Goldie prep|through art|the n|chimney'
# 'n|lie n|down adv|now'
# 'NO_UTT'
# 'co|night_night n:prop|Naomi'
# 'v|come v|look prep|at art|the n|picture prep|of art|the n|horse'
# 'EXC EXC EXC'
# 'n|moon co|yes pro:dem|that~cop|be&3S art|the n|moon'
# 'prep|up n|pen'
# 'co|oh art|the n|blanket'
# 'pro|it v|fit-3S n:prop|Nomi'
# 'mod|can n:prop|Nomi v|say'
# 'pro:dem|this cop|be&3S art|the n|way art|the n|lady v|lie-3S n|lady v|lie-3S n|lady n|lie-PL'
# 'pro:dem|that~cop|be&3S adj|right on|moo'
# 'pro:wh|what~cop|be&3S pro:dem|this art|the n|kitty aux|be&3S part|eat-PRESP n:prop|Nomi'
# 'n|fall n|down'
# 'n:prop|Mommy'
# 'mod|do~neg|not v|bang prep|on art|the n|glass'
# 'co|okay v|come adv|on v|let&ZERO pro:obj|me v|get pro|you EXC adv|here n|sweet&dadj-DIM adv|now'
# 'mod|do pro|you v|want inf|to v|blow pro:poss:det|your n|nose'
# 'n:prop|Jerry'
# 'adj|okay adj|okay pro:exist|here~cop|be&3S art|the n|crayon'
# 'EXC adj|good'
# 'EXC mod|do pro|you v|want inf|to v|smell art|the n|flower n:prop|Nomi'
# 'co|say meta|slipper n:prop|Nomi'
# 'n:prop|Mommy~poss|s n|key'
# 'v|come prep|on n|play prep|with art|the n|mouse n|house'
# 'n|flower-PL v|smell art|the n|flower-PL'
# 'v|look pro:sub|he aux|be&3S part|go-PRESP inf|to v|get prep|out_of art|the n|car'
# 'mod|do pro|you v|want inf|to v|look prep|at art|the n|book qn|some pro:indef|more'
# 'n:prop|Nomi mod|do~neg|not v|bang prep|on art|the n|glass'
# 'v|put&ZERO pro:poss:det|your n|arm adv|in'
# 'cop|be&PRES pro|you part|dance-PRESP n:prop|Nomi'
# 'adj|good n:prop|Nomi'
# 'co|oh rel|that cop|be&PAST&13S adj|good pro:sub|she v|get&PAST adv|all'
# 'pro:sub|I~mod|will v|get art|the qn|other n|slipper'
# 'EXC EXC EXC co|oh'
# 'pro:sub|I EXC'
# 'coord|and n:prop|Nomi v|say-3S'
# 'v|hit&ZERO'
# 'co|yeah pro:poss:det|its adj|good prep|for pro:poss:det|your part|dilate-PASTP n|pupil-PL'
# 'co|yes art|the n|water n|baby v|live-3S adv|here'
# 'pro|it cop|be&3S adj|empty'
# 'pro:exist|here~cop|be&3S n:prop|Goldie'
# 'EXC pro:obj|me adv|up'
# 'pro|it~aux|be&3S adj|good&CP inf|to v|build pro|it adv|on adv|here n|honey rel|where art|the n|floor cop|be&3S'
# 'co|oh EXC co|ugh'
# 'co|oh mod|do pro:sub|they v|smell adj|nice'
# 'EXC art|the adj|little n|drawer'
# 'v|remember pro:sub|we v|see&PAST n|snow'
# 'EXC co|oh n|baby'
# 'pro:wh|what v|do&3S art|the n|chick-DIM v|say n|sweet&dadj-DIM'
# 'pro:exist|there~cop|be&3S pro:indef|one pro:indef|more'
# 'v|want inf|to v|go v|see art|the n|snow'
# 'n:prop|Little_Red_Riding_Hood n:prop|Little_Red_Riding_Hood prep|on pro:poss:det|her n|way prep|to n:prop|Grandmother~poss|s n|place'
# 'v|wait n:prop|Nomi'
# 'pro:wh|what aux|be&PRES pro|you part|do-PRESP'
# 'v|want inf|to v|give n:prop|Mommy art|a n|hug'
# 'pro:exist|there~cop|be&3S art|the n|bird-DIM'
# 'n:prop|Nomi co|no'
# 'art|a n|cow'
# 'pro:dem|that~cop|be&3S neg|not art|the n|moon'
# 'pro:sub|they'
# 'pro:wh|what~aux|be&3S cop|be&3S det|this n|thing'
# 'co|night_night n|+n|sweet+n|heart'
# 'BRK BRK BRK BRK BRK n:prop|Nomi v|say'
# 'det|this pro:indef|one adv|here'
# 'pro|it~cop|be&3S art|a n|bird-DIM'
# 'co|oh pro|you v|want n|diaper n:prop|Nomi'
# 'adv|now adv:wh|how mod|do pro|you v|say'
# 'v|put&ZERO n|baby prep|in art|the n|boat'
# 'co|oh art|a adj|little n|drawer'
# 'adv:wh|where~cop|be&3S n|dog-DIM~poss|s n|tail'
# 'pro:dem|that~cop|be&3S art|a n|horse'
# 'pro|it v|happen-3S inf|to cop|be art|the n:prop|Chicago EXC coord|or pro:indef|something pro:dem|that~aux|be&3S art|a adj|big n|house'
# 'pro:wh|what EXC'
# 'adv:wh|where~cop|be&3S art|the adv:wh|where~cop|be&3S art|the n|hole n:prop|Nomi'
# 'pro:exist|there~cop|be&3S art|a n|dog-DIM'
# 'n:prop|Goldie'
# 'art|a n:prop|Little_Miss_Muffet n:prop|Little_Miss_Muffet v|sit&PAST prep|on pro:poss:det|her n|tuffet part|eat-PRESP pro:poss:det|her n|curd-PL coord|and n|whey adv|along v|come&PAST art|a'
# 'pro:wh|what aux|be&PRES pro|you part|do-PRESP n:prop|Nomi'
# 'pro:dem|this cop|be&3S art|a n|nut'
# 'adv:wh|where~cop|be&3S art|the n|rabbit'
# 'n:prop|Nomi v|say'
# 'art|a n|book'
# 'pro:sub|I~aux|be&1S part|try-PRESP inf|to v|get n|word-PL prep|with n:let|b-PL coord|and n:let|p-PL adv|now'
# 'n:prop|Mammy'
# 'v|come prep|on n:prop|Naomi n|lie adv|down pro:sub|I~aux|be&1S part|go-PRESP inf|to v|change pro:poss:det|your n|diaper EXC'
# 'co|no pro:dem|that~cop|be&3S neg|not art|the n|noon n:prop|Naomi'
# 'pro:dem|that'
# 'co|yes n:prop|Daddy'
# 'pro:dem|this cop|be&3S art|a n|slipper'
# 'pro|it~cop|be&3S n|money'
# 'pro:exist|here~cop|be&3S art|the n|horse-DIM'
# 'co|whoops n:prop|Goldie v|fall&PAST adv|out'
# 'pro:indef|nothing prep|in pro:dem|there'
# 'co|no pro|you v|lie n|down post|too'
# 'pro:dem|this cop|be&3S art|a adj|big n|shoe'
# 'co|yes pro:dem|that~cop|be&3S art|a adj|good n|girl'
# 'v|put&ZERO art|the n|coat prep|over pro:dem|here'
# 'pro:exist|there~cop|be&3S n:prop|Goldie adv|again'
# 'pro:sub|I~mod|will v|bring art|the n|paper'
# 'v|come prep|on pro:wh|what~aux|be&3S rel|that n:prop|Nomi'
# 'pro|it~aux|be&3S n:prop|Goldie'
# 'mod|can pro|you v|find qn|some n|bird-PL n:prop|Nomi'
# 'BRK n|baby'
# 'pro:dem|that~cop|be&3S adj|neat rel|that pro|you v|turn pro|it coord|and pro|it v|let-3S pro|it v|go'
# 'n:prop|Nomi n|lie n|down post|too'
# 'v|look pro:wh|what cop|be&3S adv|here n|sweet&dadj-DIM'
# 'n:prop|Nomi mod|can pro|you v|say'
# 'EXC EXC EXC EXC'
# 'v|put&ZERO n:prop|Goldie prep|through art|the n|chimney n|honey v|put&ZERO n:prop|Goldie prep|through art|the n|chimney'
# 'pro:sub|she v|say&PAST n|blanket'
# 'v|show pro:obj|me art|a n|tower v|show pro:obj|me art|a n|tower n|tower'
# 'cop|be&3S art|the n|dog-DIM part|smell-PRESP'
# 'co|no pro|it~cop|be&3S neg|not art|a n|cow'
# 'co|good_night n|baby pro|you v|get adv|up conj|when pro|you v|want prep|to adj|okay'
# 'pro:obj|me adv|down adv|up'
# 'pro:wh|what aux|be&PRES det|these n|thing-PL prep|in pro:dem|here n:prop|Nomi'
# 'pro:sub|they part|do&PASTP'
# 'pro:wh|what n|kind prep|of n|bird-DIM'
# 'aux|be&3S pro|it n:prop|Goldie'
# 'pro:wh|what~cop|be&3S pro:dem|this n:prop|Naomi rel|who cop|be&3S pro:dem|that'
# 'n|towel n|towel n|towel EXC'
# 'cop|be&3S rel|that art|a n|hat'
# 'pro:dem|that~cop|be&3S adj|dangerous n:prop|Nomi'
# 'BRK n|hat'
# 'n|doll-DIM~aux|be&3S part|stick-PRESP adv|up prep|over pro:dem|there'
# 'pro:dem|that cop|be&3S rel|where art|the adj|beautiful n|princess v|live-3S n:prop|Nomi'
# 'cop|be&3S pro:sub|she part|say-PRESP n|monkey'
# 'pro:sub|I v|want pro|you inf|to aux|be part|cover-PASTP prep|with pro:poss:det|your n|blanket'
# 'mod|can pro|you v|say meta|pupil n:prop|Nomi'
# 'qn|no art|the n|chick-DIM v|say-3S on|peep on|peep on|peep'
# 'art|the n|city prep|of n:prop|Burning n:prop|Towers'
# 'v|brush art|the n|baby~poss|s n|hair'
# 'cop|be bab|bit'
# 'pro:wh|what n:prop|Nomi'
# 'pro|you v|have det:num|one det:num|two det:num|three'
# 'mod|do pro|you v|have art|the n|slipper'
# 'n:prop|Daddy n|play'
# 'n|doll-DIM~aux|be&3S part|take-PRESP art|a n|nap'
# 'pro:wh|who cop|be&3S pro:dem|that'
# 'v|come adv|up adv|here art|a n|minute prep|with pro:obj|me'
# 'n:prop|Mommy art|a n|hug v|come v|give n:prop|Mommy art|a n|hug'
# 'art|a n|brush'
# 'pro:dem|that~cop|be&3S adv|too adj|big prep|to n|push n:prop|Nomi'
# 'v|give pro:obj|me art|a n|kiss coord|and pro:sub|I~mod|will v|get art|the EXC prep|for pro|you'
# 'EXC pro:wh|what aux|be&PRES pro:dem|those'
# 'v|put&ZERO n:prop|Goldie prep|in art|the n|house'
# 'pro:wh|what aux|be&PRES det|these n|+n|sweet+n|heart'
# 'co|yes pro:wh|what~aux|be&3S art|the n|kitty adv|in adv|here'
# 'adv:wh|where~cop|be&3S art|the n|baby'
# 'pro:wh|what~aux|be&3S art|a n|pig-DIM v|say'
# 'art|a n|house'
# 'n:prop|Nomi adv:wh|where cop|be&3S n:prop|Mama n|mouse'
# 'mod|do pro|you v|know pro:wh|what qn|any prep|of pro:dem|those cop|be&PRES'
# 'BRK n|duck'
# 'rel|who'
# 'pro:obj|me adv|down'
# 'n:prop|Nana'
# 'co|alright n:prop|Nomi pro:sub|I v|want pro|you prep|to n|nap adv|now'
# 'mod|can pro|you v|say rel|that'
# 'pro:sub|he pro:dem|that'
# 'mod|do pro|you v|want inf|to v|beep pro:poss:det|my n|nose'
# 'co|okay co|sweetie v|let~pro:obj|us v|look prep|at art|the n|book qn|some pro:indef|more'
# 'n|tea prep|in art|the n|chimney'
# 'co|ahhah n|baby coord|and pro:exist|there~cop|be&3S art|a n:prop|Mommy'
# 'pro:wh|what~cop|be&3S pro:dem|that'
# 'co|no pro:dem|that~cop|be&3S art|the n|blue pro:indef|one'
# 'v|get art|the n|green det:num|one adv|over adv|there'
# 'BRK BRK adv|up coord|and adv|up'
# 'mod|do pro|you v|want det|this pro:indef|one adv|on'
# 'pro:exist|there~cop|be&3S art|the n|hat'
# 'pro:dem|that~cop|be&3S pro:poss:det|your n|foot'
# 'pro:exist|here~cop|be&3S art|a n|kitty'
# 'v|look pro:wh|who cop|be&3S pro:dem|that'
# 'pro:wh|what aux|be&PRES det|these n|thing-PL EXC n|fish'
# 'v|do&PAST pro|you v|go prep|to art|the n|doctor adv:tem|today'
# 'co|no pro|it~cop|be&3S art|a n|baby'
# 'n:prop|Daddy'
# 'pro:dem|that~cop|be&3S art|a n|house adv|too co|yes'
# 'EXC pro:wh|what~cop|be&3S pro:dem|that'
# 'pro:wh|what cop|be&3S det|this n:prop|Nomi'
# 'conj|like n:prop|Mommy aux|have&3S adv|on'
# 'adv:wh|how~aux|be&3S det|that n|tower'
# 'co|yes pro:dem|that~cop|be&3S art|the n|dog-DIM'
# 'n:prop|Dadda'
# 'pro:sub|they mod|will v|feel art|a n|lot adj|good&CP part|close-PASTP'
# 'co|yes pro:dem|that~cop|be&3S n|right'
# 'BRK bab|woo'
# 'v|look n:prop|Nomi art|the n|car mod|do&3S~neg|not v|have qn|any n|wheel-PL prep|on pro|it'
# 'co|okay adv|now pro:sub|I v|want pro|you inf|to v|say v|say'
# 'det|this adj|little n|pig-DIM v|go&PAST inf|to v|market'
# 'adv|there pro:sub|she aux|be&3S co|yes'
# 'part|break&PASTP'
# 'v|put&ZERO adv|down'
# 'co|whoops qn|another pro:indef|one part|miss-PRESP'
# 'coord|and pro:wh|what v|do&3S art|the n|horse-DIM v|say'
# 'qn|no n|ear n:prop|Nomi'
# 'v|see art|the n|baby'
# 'v|see n:prop|Mommy'
# 'pro:dem|that~cop|be&3S art|a n|city'
# 'pro:dem|that~cop|be&3S n:prop|Nomi'
# 'BRK n|truck'
# 'pro:sub|I v|think adv|maybe n:prop|Mama~aux|be&3S part|come-PRESP n|home'
# 'EXC n|down'
# 'n:prop|Daddy~aux|be&3S part|go-PRESP inf|to v|bring art|the n|paper n|honey'
# 'pro:sub|I v|think&PAST det|those cop|be&PAST prep|among art|the n|thing-PL rel|that pro|you v|put&ZERO adv|away'
# 'adv:wh|how adj|big aux|be&3S'
# 'pro:dem|that~cop|be&3S art|the n|red pro:indef|one'
# 'det:wh|what v|do n|kitty-PL v|eat'
# 'BRK adv:wh|how'
# 'pro:wh|what cop|be&PAST&13S rel|that n:prop|Naomi'
# 'co|ahhah coord|and art|a n|cow v|say-3S'
# 'pro|you mod|can v|see art|a n|car adv|out rel|that n|window'
# 'n|lie prep|down n:prop|Naomi conj|so pro:sub|we mod|can v|change pro:poss:det|your n|diaper'
# 'pro:sub|we v|have art|a n|disaster conj|if pro|you v|bang prep|on art|the n|glass'
# 'qn|no n|red pro:indef|one adj|first n:prop|Nomi'
# 'EXC'
# 'n|play prep|with art|the n|bird-DIM'
# 'co|oh prep|up EXC'
# 'mod|can pro:sub|she v|reach pro:dem|this'
# 'co|yes adv|there pro|it cop|be&3S'
# 'pro:wh|what~aux|be&3S rel|that n:prop|Naomi'
# 'pro:dem|that~cop|be&3S adj|right n|bird-PL cop|be&PRES adv|there'
# 'EXC on|oig on|oig'
# 'cop|be&3S n:prop|Nomi part|write-PRESP art|the n|dog~poss|s n|tail'
# 'prep|up n|down'
# 'EXC n|pen'
# 'BRK BRK n|car'
# 'qn|no n|+n|sweet+n|heart pro|you adv|just v|go&PAST n|pot-DIM'
# 'v|sit prep|down n|brush n|hair'
# 'pro:wh|what aux|be&3S det|this'
# 'pro:wh|what~aux|be&3S part|break&PASTP n:prop|Nomi'
# 'co|yeah pro:dem|that~cop|be&3S n:prop|Contrary_Mary~poss|s n|garden'
# 'pro:wh|what'
# 'prep|at art|the n|bottom n:prop|Nomi'
# 'EXC mod|do pro|you v|want inf|to v|turn pro:dem|that'
# 'det:wh|what aux|be&PRES pro:sub|they part|eat-PRESP'
# 'co|yes coord|and pro:dem|these cop|be&PRES n|chick-DIM-PL'
# 'pro:dem|that~cop|be&3S EXC n|slipper'
# 'co|well v|let~pro:obj|us v|have qn|some n:let|d n:let|i n:let|n n:let|n n:let|e n:let|r'
# 'co|yes n:prop|Mommy coord|and art|a n:prop|Daddy'
# 'n:prop|Flipper'
# 'n:prop|Nomi v|need-3S adj|big-CP n|ear-PL'
# 'pro:sub|she v|say-3S n|shoe adv|very adv|nice&dadj-LY adv|now'
# 'adj|poor n:prop|Goldie'
# 'co|yes coord|and pro:exist|here cop|be&3S art|a n|kitty'
# 'n|baby aux|be&3S part|take-PRESP art|a n|nap'
# 'n|dog-DIM EXC'
# 'co|yes EXC EXC EXC adv|pretty co|huh'
# 'pro:dem|that~cop|be&3S art|a n|kitty co|huh'
# 'pro:dem|that~cop|be&3S adj|dangerous'
# 'n:prop|Naomi v|get&PAST adv|up adv|already'
# 'n|stay prep|in pro:dem|here n:prop|Daddy~aux|be&3S part|go-PRESP inf|to v|bring art|the n|paper'
# 'pro|you v|lie adv|down adv|too pro|you v|lie adv|down prep|with art|the n|baby'
# 'mod|do pro:sub|they v|smell adv|pretty'
# 'co|boy BRK BRK adj|big'
# 'n|baby BRK n|duck'
# 'v|let~pro:obj|us v|call pro|it EXC v|say n|shoe'
# 'pro|you adv|just v|go&PAST n|pot-DIM adv|now pro|it cop|be&3S v|time inf|to v|go prep|to n|sleep'
# 'coord|and pro:wh|what cop|be&3S det|this art|a n|pig-DIM'
# 'v|tell pro:obj|me adv|again pro:wh|what aux|be&3S det|this'
# 'pro:dem|that~cop|be&3S art|a n|baby'
# 'n:prop|Daddy n|dog-DIM'
# 'adj|care&dn-FULL'
# 'cop|be&PRES pro|you part|ride-PRESP pro:poss:det|your chi|gogo'
# 'v|lie pro:obj|me adv|down'
# 'co|yes n:prop|Goldie v|write prep|down n:prop|Goldie'
# 'pro:dem|that~cop|be&3S pro:poss:det|your n|ear'
# 'EXC n|baby'
# 'pro:exist|here~cop|be&3S art|the n|tail n:prop|Nomi'
# 'co|yeah co|well pro:dem|that~cop|be&3S pro:wh|what pro:sub|I v|think&PAST'
# 'n|blanket n:prop|Nomi'
# 'v|go prep|in art|the n|kitchen coord|and v|see n:prop|Daddy'
# 'co|yes n|snow prep|at art|the n|window co|huh'
# 'co|yes rel|that cop|be&3S art|a n|house'
# 'v|bite&PAST conj|but'
# 'pro:sub|he aux|be&3S part|go-PRESP prep|to n|turn prep|off art|the n|light-PL'
# 'pro:wh|what pro:obj|me prep|to co|help'
# 'aux|be&3S pro|it art|a n|chicken'
# 'pro:wh|what~cop|be&3S pro:dem|this'
# 'mod|do pro|you v|want art|a n|crayon'
# 'cop|be&3S art|the n|horse-DIM aux|be-PRESP co|careful'
# 'pro:dem|that~cop|be&3S art|a n|ball'
# 'on|oig on|oig on|oig EXC'
# 'pro:sub|she v|go&PAST coord|and v|get&PAST art|the n|diaper prep|after n:gerund|say-PRESP meta|dupper coord|or pro:wh|what adv|ever pro|it cop|be&PAST&13S'
# 'adv|up prep|down pro:poss:det|your part|dance-PRESP'
# 'pro:sub|they aux|be&PRES part|call-PASTP n|glass-PL'
# 'adv:wh|where~cop|be&3S art|the n|blanket'
# 'pro|it~cop|be&3S art|a n|horse'
# 'BRK n|house'
# 'EXC adj|kit&dn-Y'
# 'pro|you adv|still mod|do~neg|not v|have pro:poss:det|your n|slipper prep|on n|babe'
# 'adv|now v|get art|the n|red det:num|one n:prop|Nomi'
# 'pro:sub|he art|a n|pot-DIM'
# 'BRK adv|pretty'
# 'pro:poss|mine'
# 'mod|do pro|you v|remember pro:wh|what art|the n|horse-DIM v|say-3S'
# 'pro:dem|that~cop|be&3S pro:wh|what art|the n|pig-DIM v|say-3S on|oink on|oink co|yeah'
# 'pro:sub|I v|think n:prop|Mama~poss|s part|come-PRESP prep|up art|the n|stair-PL'
# 'pro:wh|what v|do&3S art|the n|dog-DIM v|say'
# 'adv:wh|how co|oh'
# 'pro:wh|what aux|be&PRES pro:dem|those'
# 'n|horse-DIM adv|right v|want inf|to v|build art|a n|tower'
# 'adj|dangerous n:prop|Nomi'
# 'adj|red pro:indef|one'
# 'adv:wh|how'
# 'pro:wh|what~cop|be&3S pro:dem|this n:prop|Nomi'
# 'adv:wh|where~cop|be&3S art|a n|fish n:prop|Nomi'
# 'EXC EXC EXC EXC EXC'
# 'v|let&ZERO pro:obj|me v|see'
# 'cop|be&3S adv|there art|a n|mouse prep|in pro:dem|there'
# 'n:prop|Goldie v|fall&PAST adv|down'
# 'v|look prep|at pro:dem|that'
# 'co|yes rel|that cop|be&3S n:prop|Nomi prep|in art|the n|mirror'
# 'co|oh co|oh v|look prep|at pro|it v|spin'
# 'pro:wh|what v|do&3S art|the n|pig-DIM v|say'
# 'co|whoopsie n:prop|Goldie v|fall&PAST adv|down adv|again'
# 'co|okay pro:dem|that~cop|be&3S adj|nice'
# 'pro:sub|she~cop|be&3S'
# 'n|pupil-PL pro:wh|what~poss|s art|a n|pupil'
# 'n:prop|Jerry v|make&PAST rel|that'
# 'EXC v|look n:prop|Nomi art|a part|color-PRESP n|book'
# 'n|cow n|cow v|jump-PAST prep|over art|the n|moon v|read&ZERO n:prop|Little_Miss_Muffet'
# 'n|spoon adv:wh|where~cop|be&3S art|the n|spoon'
# 'pro:wh|what~aux|be&3S rel|that n:prop|Nomi'
# 'pro:exist|there~cop|be&3S art|the n|red pro:indef|one'
# 'v|go v|find v|get art|the n|doll-DIM coord|and v|brush art|the n|doll-DIM~poss|s n|hair'
# 'pro:exist|here~cop|be&3S qn|another n|horse n:prop|Nomi'
# 'co|night_night n|sweet&dadj-DIM'
# 'pro|you v|lie adv|down adv|too prep|with art|the n|baby'
# 'v|say pro|it adv|again n|sweet&dadj-DIM'
# 'adj|kit&dn-Y'
# 'pro|it mod|do&3S~neg|not v|fit&ZERO'
# 'qn|no n|red pro:indef|one adj|first'
# 'mod|will pro|you v|come adv|in adv|here coord|and BRK BRK BRK BRK BRK pro:sub|we~mod|will v|play prep|with art|the n|mouse n|house'
# 'v|come adv|on prep|in pro:dem|here'
# 'v|fall&PAST adv|down'
# 'n:prop|Naomi n|brush n:prop|Naomi part|brush-PRESP'
# 'pro:dem|this cop|be&3S art|the n|tongue n:prop|Nomi'
# 'coord|and pro:exist|here~cop|be&3S art|the n|spider'
# 'EXC pro:dem|that~cop|be&3S art|the adj|ease&dn-Y n|way'
# 'co|no pro:sub|I mod|do~neg|not v|think co|so'
# 'co|oh art|the n|glass-PL aux|be&PRES part|break&PASTP'
# 'cop|be n|care-FUL adv|now pro|you~mod|will part|hit&PASTP pro:poss:det|your n|head'
# 'n:prop|Nomi'
# 'adv|here v|let~pro:obj|us v|put&ZERO pro|it v|like pro:dem|this conj|so pro:sub|she mod|will~neg|not v|fall adv|again'
# 'art|the n|donkey aux|be&3S part|dance-PRESP part|dance-PRESP part|dance-PRESP'
# 'art|a adj|empty n|drawer'
# 'pro:dem|that~cop|be&3S art|a n|walrus'
# 'v|put&ZERO pro:poss:det|your n|head n|down'
# 'v|leave pro|it adv|over adv|here conj|while pro:sub|we~cop|be&PRES neg|not part|use-PRESP pro|it'
# 'pro:dem|that~cop|be&3S art|the n|tongue'
# 'mod|do pro|you v|put&ZERO pro:dem|this prep|on art|the n|floor n:prop|Nomi'
# 'n:prop|Nomi pro:dem|this cop|be&3S art|a n|vase'
# 'v|go prep|to art|the n|door prep|in art|the n|kitchen prep|in art|the n|kitchen n|honey'
# 'co|yes rel|that cop|be&3S pro:wh|what art|the n|horse-DIM v|say-3S'
# 'v|fall&PAST adv|down adv|again'
# 'pro:sub|she adv|never v|realize-3S adv:wh|how adj|big art|a n|piece'
# 'pro:wh|who~cop|be&3S pro:dem|that n|sweet&dadj-DIM'
# 'adj|kit&dn-Y n:gerund|eat-PRESP'
# 'v|put&ZERO n:prop|Goldie prep|through art|the n|chimney n|honey'
# 'det:num|one n|mouse'
# 'n|ear adv:wh|where~cop|be&3S n|dog-DIM'
# 'co|oh n:prop|Nomi'
# 'n:prop|Naomi pro:wh|what~cop|be&3S pro:dem|that'
# 'art|a on|oig BRK BRK art|a on|oig on|oig'
# 'mod|do~neg|not v|draw co|no co|no mod|do~neg|not v|draw'
# 'cop|be&3S det|this pro:poss:det|your n|slipper'
# 'pro:dem|that~cop|be&3S n|right'
# 'v|do&PAST pro|you v|lose art|a n|crayon co|honey'
# 'coord|and pro:wh|what v|do&3S art|a n|chick-DIM v|say'
# 'adv:wh|where~cop|be&3S art|the n|bird-DIM'
# 'pro:exist|there~cop|be&3S art|the n|paper n|honey coord|and art|the n|book'
# 'BRK bab|gaga'
# 'conj|if pro|you v|want inf|to v|call pro|it rel|that pro|it~cop|be&3S adj|fine prep|with pro:obj|me'
# 'BRK pro:sub|they part|do&PASTP'
# 'adj|lay n|down'
# 'pro:sub|I v|think n:prop|Nomi aux|be&3S part|tire-PASTP'
# 'BRK on|oig bab|ye'
# 'art|a n|puppy'
# 'pro:dem|that~cop|be&3S adj|red'
# 'pro:wh|what aux|be&PRES det|those n|kitty-PL part|eat-PRESP co|sweetie'
# 'co|yeah conj|but pro:sub|I v|decide-PAST adv|maybe pro:sub|she mod|will&COND aux|be part|learn-PRESP inf|to v|use pro:obj|them adv|very adv|soon'
# 'pro:dem|these cop|be&PRES n|flower-PL'
# 'art|the n|car mod|do&3S~neg|not v|have qn|any n|wheel-PL pro|it~aux|be&3S part|break&PASTP'
# 'pro:dem|that~cop|be&3S art|a n|house'
# 'pro:exist|here~cop|be&3S art|a n|white pro:indef|one'
# 'co|yes pro:dem|that~cop|be&3S art|a n|house'
# 'v|put&ZERO art|the n|blanket prep|on art|the n|baby'
# 'n|blanket n|sweet&dadj-DIM'
# 'n:prop|Daddy co|haha co|haha'
# 'BRK n|rabbit'
# 'adv:wh|how v|do&3S art|the n|bird-DIM v|go'
# 'adv|actual&dadj-LY n:prop|Mommy pro|it~cop|be&3S art|a n|bear'
# 'pro:wh|what n:prop|Mommy mod|do&3S n:prop|Nomi v|cast-3S adv|asunder'
# 'pro|you v|lie n|down coord|and v|close det|those n|eye-PL'
# 'pro:wh|what aux|be&PRES det|these n:prop|Nomi'
# 'pro:exist|here~cop|be&3S art|a n|mouse'
# 'v|go v|see n:prop|Daddy adj|okay n:prop|Naomi v|say pro:indef|something'
# 'pro:exist|there~cop|be&3S art|the n|fish'
# 'n:prop|Mama n|mouse'
# 'qn|no n|walrus n:prop|Naomi'
# 'v|brush art|the n|doll-DIM~poss|s n|hair n:prop|Nomi'
# 'n:prop|Naomi'
# 'adv:wh|where~cop|be&3S art|the n|rabbit~poss|s n|hole'
# 'v|go prep|to art|the n|door n|honey'
# 'det|that n|dog-DIM~poss|s n|tail'
# 'co|no pro|it~cop|be&3S neg|not art|a n|dog-DIM'
# 'co|honey pro:wh|what aux|be&PRES pro:dem|these'
# 'n|lie n|down adv|here n|sweet-PL'
# 'adv:wh|where~cop|be&3S art|a n|boat'
# 'n:prop|Goldie co|yeah'
# 'rel|whose rel|that adv|here'
# 'qn|another n|baby prep|in art|the n|boat'
# 'co|look co|look co|look pro:exist|there cop|be&3S art|a n|car'
# 'adv|here pro|it cop|be&3S n:prop|Nomi art|the n|book cop|be&3S prep|in pro:dem|here'
# 'EXC det:wh|what aux|be&PRES pro:sub|they'
# 'mod|do~neg|not v|draw prep|on art|the n|baby'
# 'art|a n|shoe'
# 'pro:wh|what cop|be&PAST&13S pro:dem|that'
# 'v|+n|night+v|night'
# 'n:prop|Daddy v|go v|see n:prop|Daddy'
# 'pro:exist|here~cop|be&3S art|the n|bird-DIM'
# 'pro:wh|what aux|be&3S pro|it'
# 'v|get det|that n|ball'
# 'co|say meta|broken n:prop|Nomi'
# 'EXC EXC'
# 'pro:dem|that~cop|be&3S n|horse-DIM'
# 'pro:sub|she~cop|be&3S prep|over pro:dem|there pro:sub|she~cop|be&3S adv|there'
# 'n|brush n|baby~poss|s n|hair'
# 'co|night_night n:prop|Nomi'
# 'pro:dem|that~cop|be&3S adj|right pro|it v|go-3S adv|in adv|here n|+n|sweet+n|heart'
# 'co|oh pro|it~cop|be&3S art|a n|kitty'
# 'BRK BRK adj|wee'
# 'pro:dem|that~cop|be&3S art|a'
# 'n:prop|Nomi v|put&ZERO pro|it adv|in'
# 'n|horse neg|not art|a n|pig-DIM'
# 'adv:wh|how adj|big aux|be&3S n:prop|Nomi'
# 'qn|no co|no n|lie adv|down co|sweetheart n|lie adv|down'
# 'pro:exist|there cop|be&3S art|a n|car adv|out adv|there'
# 'pro|it~aux|be&3S part|get-PRESP adv|more coord|and adv|more adj|difficult aux|be&3S~neg|not pro|it n:prop|Nomi'
# 'pro:dem|that~cop|be&3S art|a n|cow'
# 'EXC n:prop|Daddy'
# 'v|put&ZERO n|baby co|night_night n|honey'
# 'adv:wh|where~cop|be&3S art|the n|pig-DIM'
# 'BRK co|bye'
# 'pro|you mod:aux|have_to v|get adj|big-CP n|ear-PL'
# 'part|break&PASTP part|break&PASTP'
# 'cop|be&3S rel|that art|a n|house'
# 'v|read&ZERO art|a n|book'
# 'pro:sub|I v|put&ZERO pro:dem|that prep|down art|the adj|wrong n|way'
# 'adv|over adv|there prep|by art|the n|bed'
# 'pro:wh|what~aux|be&3S art|the n|dog-DIM part|do-PRESP'
# 'co|oh EXC'
# 'co|oh rel|that n|baby co|yes pro|you v|get art|the n|baby'
# 'v|show art|the n|dog-DIM'
# 'n|mouse pro:dem|that~aux|be&3S neg|not art|a n|mouse n:prop|Nomi pro:dem|that~cop|be&3S art|a n|house'
# 'pro:wh|what~cop|be&3S pro:dem|this n|honey'
# 'rel|whose pro:dem|that adv|in adv|there'
# 'pro:sub|I mod|can v|put&ZERO art|a EXC adv|in adv|here adv|too adv|now pro:sub|I v|think'
# 'co|see v|want pro:obj|me inf|to v|wash pro:poss:det|your n|tooth&PL'
# 'cop|be&1S pro:sub|I n|right'
# 'v|come prep|on n|sweet&dadj-DIM'
# 'cop|be&3S rel|that art|a n|toy'
# 'adv|here co|sweetie pro:exist|here~cop|be&3S art|a n|tissue prep|for pro|you'
# 'cop|be&3S rel|that co|alright'
# 'pro:wh|what~cop|be&3S pro:dem|this n|+n|sweet+n|heart'
# 'co|yeah part|break&PASTP'
# 'adj|good pro|it~cop|be&3S n|flower'
# 'v|do&PAST pro|you v|leave art|the qn|other n|slipper adv|outside n:prop|Nomi'
# 'pro:sub|I v|want inf|to v|hold pro|you prep|for art|a n|minute'
# 'pro:wh|what n|kind prep|of n|bird-DIM aux|be&3S pro|it'
# 'v|put&ZERO art|the n|blanket prep|on art|the n|baby n:prop|Nomi'
# 'v|bring art|the qn|other v|piece-3S n:prop|Nomi'
# 'adj|chic aux|be&3S rel|that art|a n|tree'
# Items in the second set but not the first:
# ''
# 'pro|that cop|be det|a n|kitty co|huh'
# 'pro|this cop|be-3S det|a n|nut'
# 'pro|she v|go-PAST coord|and v|get-PAST det|the n|diaper prep|after n|say-PRESP meta|dupper coord|or pro|what adv|ever pro|it cop|be-PAST'
# 'v|do-PAST pro|you v|lose det|a n|crayon n|honey'
# 'n|Daddy v|go v|see n|Daddy'
# 'v|put-ZERO n|baby co|night_night n|honey'
# 'det|what aux|be-PRES pro|they part|eat-PRESP'
# 'co|look co|look co|look adv|there cop|be-3S det|a n|car'
# 'mod|do pro|you v|want inf|to v|beep det|my n|nose'
# 'pro|that cop|be det|your n|foot'
# 'pro|what n|Nomi'
# 'n|Jerry'
# 'mod|do pro|you v|remember pro|what det|the n|horse-DIM v|say-3S'
# 'None|how adv|how'
# 'cop|be-3S pro|that adj|alright'
# 'pro|here cop|be n|Goldie'
# 'adv|up prep|down det|your part|dance-PRESP'
# 'mod|do neg|not v|draw prep|on det|the n|baby'
# 'co|oh pro|that cop|be-PAST adj|good pro|she v|get-PAST adv|all'
# 'pro|what cop|be-PAST pro|that'
# 'None|xxx n|Daddy'
# 'n|Mama n|mouse'
# 'coord|and pro|what v|do-3S det|a n|chick-DIM v|say'
# 'cop|be-PRES pro|you part|dance-PRESP n|Nomi'
# 'pro|what aux|be-PRES pro|these n|sweet'
# 'mod|do pro|you v|want inf|to cop|look prep|at det|the n|book qn|some pro|more'
# 'None|yyy on|oig on|oig'
# 'n|mouse pro|that aux|be neg|not det|a n|mouse n|Nomi pro|that cop|be det|a n|house'
# 'None|duck n|duck'
# 'None|eh None|ah None|eh co|ah'
# 'n|Mommy poss|s n|key'
# 'pro|me adv|down adv|up'
# 'co|okay v|get det|the n|green det|one n|Nomi'
# 'adv|where cop|be det|the adv|where cop|be det|the n|hole n|Nomi'
# 'None|truck n|truck'
# 'adv|where cop|be det|the n|house n|Naomi'
# 'pro|that cop|be adj|right pro|it v|go-3S adv|in adv|here n|sweet'
# 'pro|she cop|be'
# 'co|oh None|uh'
# 'co|no pro|you v|lie adv|down post|too'
# 'n|pupil-PL pro|what poss|s det|a n|pupil'
# 'pro|what None|xxx'
# 'pro|whose pro|that prep|in adv|there'
# 'pro|I v|put-ZERO pro|that prep|down det|the adj|wrong n|way'
# 'pro|here cop|be det|a n|white pro|one'
# 'n|ear pro|where aux|be n|dog-DIM'
# 'n|Nomi mod|do neg|not v|bang prep|on det|the n|glass'
# 'pro|that cop|be pro|what det|the n|pig-DIM v|say-3S on|oink on|oink co|yeah'
# 'adv|how v|do-3S det|the n|bird-DIM v|go'
# 'n|Daddy'
# 'n|Nomi n|lie adv|down post|too'
# 'pro|that cop|be n|right'
# 'co|okay co|okay pro|here cop|be det|the n|crayon'
# 'adv|where cop|be det|the n|rabbit'
# 'co|oh pro|you v|want n|diaper n|Nomi'
# 'None|ah None|ah None|ah None|ah co|ah'
# 'n|lie adv|down adv|here n|sweet-PL'
# 'n|Dadda'
# 'coord|and pro|what cop|be-3S pro|this det|a n|pig-DIM'
# 'mod|can pro|you v|say pro|that'
# 'None|uh'
# 'n|kitty part|eat-PRESP'
# 'n|Daddy aux|be part|go-PRESP inf|to v|bring det|the n|paper n|honey'
# 'pro|you mod|have_to v|get adj|big-CP n|ear-PL'
# 'None|xxx'
# 'v|want inf|to v|put-ZERO det|the n|glass-PL adv|on'
# 'None|oig on|oig bab|ye'
# 'co|hm pro|what cop|be pro|that'
# 'v|come adv|here coord|and cop|look prep|at det|the n|book prep|with n|Mommy'
# 'mod|do neg|not v|bang prep|on det|the n|glass'
# 'co|careful'
# 'pro|what n|kind prep|of n|bird-DIM'
# 'pro|this cop|be-3S det|a n|windmill'
# 'pro|what-PRES pro|what aux|be-PRES pro|you part|do-PRESP'
# 'adj|dangerous n|Nomi'
# 'n|mouse pro|that aux|be n|baby n|mouse n|Nomi'
# 'v|bring det|the qn|other n|piece-PL n|Nomi'
# 'v|remember pro|we v|see-PAST n|snow'
# 'v|come prep|on n|Naomi n|lie adv|down pro|I aux|be part|go-PRESP inf|to v|change det|your n|diaper co|hm'
# 'co|yes coord|and adv|here cop|be-3S det|a n|kitty'
# 'co|night_night n|sweet'
# 'cop|be co|careful adv|now pro|you mod|will part|hit-PASTP det|your n|head'
# 'adv|where cop|be det|the n|bird-DIM'
# 'None|bye co|bye'
# 'cop|look prep|at det|the n|bottom'
# 'None|eh co|ah co|ah co|oh'
# 'co|oh det|the n|glass-PL aux|be-PRES part|break-PASTP'
# 'n|tea prep|in det|the n|chimney'
# 'co|yes pro|what aux|be det|the n|kitty prep|in adv|here'
# 'co|okay pro|that cop|be adj|nice'
# 'pro|what aux|be det|the n|kitty part|eat-PRESP'
# 'pro|who aux|be pro|that co|sweetie'
# 'cop|be-3S pro|she part|say-PRESP n|monkey'
# 'pro|what aux|be-PRES pro|these n|thing-PL prep|in adv|here n|Nomi'
# 'n|tree None|yyy n|Daddy'
# 'aux|be-3S pro|it det|a n|blanket'
# 'v|tell pro|me adv|again pro|what cop|be-3S pro|this'
# 'None|xxx None|yyy None|yyy'
# 'pro|that cop|be adj|right on|moo'
# 'adv|actual-dadj n|Mommy pro|it cop|be det|a n|bear'
# 'None|um n|kitty'
# 'qn|no qn|no n|lie adv|down n|sweet n|lie adv|down'
# 'pro|what aux|be-3S pro|it'
# 'pro|that cop|be adj|dangerous n|Nomi'
# 'co|yeah conj|but pro|I v|decide-PAST adv|maybe pro|she mod|will-COND aux|be part|learn-PRESP inf|to v|use pro|them adv|very adv|soon'
# 'None|Daddy n|Daddy'
# 'pro|that cop|be None|xxx n|slipper'
# 'co|see v|want pro|me inf|to v|wash det|your n|tooth-PL'
# 'v|lie pro|me adv|down'
# 'pro|this cop|be-3S det|a n|slipper'
# 'co|okay co|sweetie v|let pro|us cop|look prep|at det|the n|book qn|some pro|more'
# 'n|Nomi v|need-3S adj|big-CP n|ear-PL'
# 'co|oh mod|do pro|they v|smell adj|nice'
# 'pro|here cop|be det|a n|kitty'
# 'adv|here v|let pro|us v|put-ZERO pro|it v|like pro|this conj|so pro|she mod|will neg|not v|fall adv|again'
# 'co|look pro|what cop|be-3S adv|here co|sweetie'
# 'co|well v|let pro|us v|have qn|some n|d n|i n|n n|n n|e n|r'
# 'co|yes det|the n|water n|baby v|live-3S adv|here'
# 'v|put-ZERO n|Goldie prep|through det|the n|chimney n|honey'
# 'n|moon co|yes pro|that cop|be det|the n|moon'
# 'n|Little_Red_Riding_Hood n|Little_Red_Riding_Hood prep|on pro|her n|way prep|to n|Grandmother poss|s n|place'
# 'mod|can n|Nomi v|say'
# 'v|flower-3S n|smell det|the n|flower-PL'
# 'pro|that det|a n|girl'
# 'n|Nomi v|come adv|on cop|look prep|at det|the n|book cop|look prep|at det|the n|book'
# 'v|put-ZERO n|Goldie prep|through det|the n|chimney n|honey v|put-ZERO n|Goldie prep|through det|the n|chimney'
# 'None|eh co|ah'
# 'co|say meta|broken n|Nomi'
# 'None|yyy'
# 'co|oh pro|that n|baby co|yes pro|you v|get det|the n|baby'
# 'v|see det|the n|baby'
# 'v|give pro|me det|a n|kiss coord|and pro|I mod|will v|get det|the None|xxx prep|for pro|you'
# 'pro|they pro|they part|do-PASTP'
# 'pro|they mod|will v|feel det|a n|lot adj|good-CP part|close-PASTP'
# 'n|Flipper'
# 'pro|we v|have det|a n|disaster conj|if pro|you v|bang prep|on det|the n|glass'
# 'pro|what cop|be pro|this n|sweet'
# 'coord|and pro|what v|do-3S det|the n|horse-DIM v|say'
# 'n|Mommy det|a n|hug v|come v|give n|Mommy det|a n|hug'
# 'adv|where cop|be det|the n|baby'
# 'v|leave pro|it adv|over adv|here conj|while pro|we aux|be neg|not part|use-PRESP pro|it'
# 'pro|it cop|be n|money'
# 'None|xxx n|pen'
# 'n|lie adv|down adv|now'
# 'pro|there cop|be det|the n|paper n|honey coord|and det|the n|book'
# 'pro|she v|say-PAST n|blanket'
# u'adv|how None|house None|house n|house'
# 'pro|whose pro|that adv|here'
# 'n|play prep|with det|the n|bird-DIM'
# 'pro|that cop|be det|the n|tongue'
# 'co|yes pro|that cop|be n|right'
# 'qn|another n|baby prep|in det|the n|boat'
# 'adv|up n|pen'
# 'adv|there pro|she v|go-3S'
# 'pro|what cop|be pro|this n|Naomi pro|who cop|be-3S pro|that'
# 'mod|can pro|you v|find qn|some n|bird-PL n|Nomi'
# 'n|Nomi co|no'
# 'adj|good n|Nomi'
# 'cop|be-3S det|the n|dog-DIM part|smell-PRESP'
# 'pro|what cop|be pro|this'
# 'v|wait n|Nomi'
# 'n|Nomi v|say'
# 'co|mm'
# 'co|whoops n|Goldie v|fall-PAST adv|out'
# 'co|no pro|it cop|be det|a n|baby'
# 'co|whoopsie pro|here cop|be det|a n|tissue prep|for pro|you'
# 'v|night'
# 'adv|there cop|be-3S det|a n|car adv|out adv|there'
# 'cop|be-3S n|Nomi part|write-PRESP det|the n|dog poss|s n|tail'
# 'pro|I v|think adv|maybe n|Mama aux|be part|come-PRESP n|home'
# 'n|Nomi'
# 'pro|they mod|will neg|not n|stay prep|on det|your n|ear-PL n|Nomi'
# 'adv|where cop|be det|a n|boat'
# 'v|want inf|to v|give n|Mommy det|a n|hug'
# 'pro|here cop|be det|a n|mouse'
# 'co|whoops qn|another pro|one part|miss-PRESP'
# 'mod|do pro|you v|have det|the n|slipper'
# 'co|say meta|slipper n|Nomi'
# 'None|xxx None|yyy'
# 'pro|here cop|be det|the n|horse-DIM'
# 'pro|that cop|be det|a n|walrus'
# 'n|brush n|baby poss|s n|hair'
# 'pro|what n|Mommy mod|do-3S n|Nomi n|cast-PL adv|asunder'
# 'pro|here cop|be qn|another n|horse n|Nomi'
# 'pro|I mod|will v|get det|the qn|other n|slipper'
# 'v|fall-PAST adv|down'
# 'n|Nana'
# 'co|oh pro|it cop|be det|a n|kitty'
# 'pro|there cop|be det|the n|red pro|one'
# 'qn|no det|the n|chick-DIM v|say-3S on|peep on|peep on|peep'
# 'v|go prep|to det|the n|door prep|in det|the n|kitchen prep|in det|the n|kitchen n|honey'
# 'pro|it v|happen-3S inf|to cop|be det|the n|Chicago None|xxx coord|or pro|something pro|that aux|be det|a adj|big n|house'
# 'pro|what aux|be cop|be-3S pro|this n|thing'
# 'co|yes pro|that cop|be det|a adj|good n|girl'
# 'None|yyy co|ah'
# 'pro|it v|fit-3S n|Nomi'
# 'adv|where cop|be det|the n|pig-DIM'
# 'prep|at det|the n|bottom n|Nomi'
# 'n|Nomi pro|this cop|be-3S det|a n|vase'
# 'adv|where cop|be det|a n|fish n|Nomi'
# 'co|yes pro|that cop|be det|a n|house'
# 'co|yes det|the n|baby aux|be-3S part|lie-PRESP adv|down'
# 'qn|no n|walrus n|Naomi'
# 'qn|no n|red pro|one adj|first'
# 'pro|what aux|be-PRES pro|you part|do-PRESP n|Nomi'
# 'pro|it aux|be adj|good-CP inf|to v|build pro|it prep|on adv|here n|honey pro|where det|the n|floor cop|be-3S'
# 'v|show pro|me det|a n|tower v|show pro|me det|a n|tower n|tower'
# 'cop|be-3S det|the n|horse-DIM aux|be-PRESP co|careful'
# 'co|yes n|snow prep|at det|the n|window co|huh'
# 'cop|be-3S pro|this det|your n|slipper'
# 'cop|be-3S pro|that det|a n|house'
# 'n|Mommy'
# 'None|car None|car n|car'
# 'pro|it cop|be det|a n|bird-DIM'
# 'n|Naomi'
# 'co|ah'
# 'det|a n|ball'
# 'det|a n|cow'
# 'adv|over adv|there prep|by det|the n|bed'
# 'pro|it mod|do-3S neg|not v|fit-ZERO'
# 'n|Nomi v|put-ZERO pro|it adv|in'
# 'v|brush det|the n|baby poss|s n|hair'
# 'co|yeah co|well pro|that cop|be pro|what pro|I v|think-PAST'
# 'pro|here cop|be det|the n|tail n|Nomi'
# 'n|Naomi n|brush n|Naomi part|brush-PRESP'
# 'pro|that cop|be neg|not det|the n|moon'
# 'mod|can pro|you v|find det|a n|fish'
# 'n|kitty'
# 'cop|be-3S pro|that det|a n|toy'
# 'pro|here cop|be det|the n|bird-DIM'
# 'pro|who cop|be-3S pro|that'
# 'None|hat n|hat'
# 'pro|what cop|be-3S pro|this n|honey'
# 'conj|if pro|you v|want inf|to v|call pro|it pro|that pro|it cop|be adj|fine prep|with pro|me'
# 'pro|he det|a n|pot-DIM'
# 'aux|be-1S pro|I n|right'
# 'pro|that cop|be det|the n|red pro|one'
# 'v|do-PAST pro|you v|leave det|the qn|other n|slipper adv|outside n|Nomi'
# 'co|ah co|oh co|night_night'
# 'v|come prep|on pro|what aux|be pro|that n|Nomi'
# u'None|up None|and adv|up coord|and adv|up'
# 'pro|here cop|be det|a n|boat'
# 'co|no pro|that cop|be det|the n|blue pro|one'
# 'conj|like n|Mommy aux|have-3S adv|on'
# 'n|cow n|cow v|jump-PAST prep|over det|the n|moon v|read-ZERO n|Little_Miss_Muffet'
# 'None|xxx mod|do pro|you v|want inf|to v|smell det|the n|flower n|Nomi'
# 'pro|mine'
# 'n|Goldie adv|just mod|do-3S neg|not v|want inf|to v|sit prep|in adv|there v|do-3S pro|she'
# 'cop|look pro|he aux|be-3S part|go-PRESP inf|to v|get prep|out_of det|the n|car'
# 'None|xxx det|the adj|little n|drawer'
# 'on|oig on|oig on|oig None|yyy'
# 'v|come cop|look prep|at det|the n|picture prep|of det|the n|horse'
# 'v|see n|Mommy'
# 'pro|what cop|be-3S pro|this'
# 'pro|what n|kind prep|of n|bird-DIM aux|be-3S pro|it'
# 'adv|here co|sweetie pro|here cop|be det|a n|tissue prep|for pro|you'
# 'det|one n|mouse'
# 'co|good_night v|baby pro|you v|get adv|up conj|when pro|you v|want prep|to adj|okay'
# 'v|hit-ZERO'
# 'v|say pro|it adv|again co|sweetie'
# 'v|come prep|on n|play prep|with det|the n|mouse n|house'
# 'adv|there pro|she aux|be-3S co|yes'
# 'adv|now adv|how mod|do pro|you v|say'
# 'pro|you v|lie adv|down adv|too prep|with det|the n|baby'
# 'qn|no n|ear n|Nomi'
# 'mod|do pro|you v|want inf|to v|blow det|your n|nose'
# 'n|Naomi pro|what cop|be pro|that'
# 'n|Mammy'
# 'pro|that cop|be det|a'
# 'n|Nomi pro|what cop|be pro|this'
# 'adj|good pro|it cop|be n|flower'
# 'adv|up adv|down'
# 'pro|this cop|be-3S det|the n|way det|the n|lady n|lie-PL n|lady n|lie-PL n|lady n|lie-PL'
# 'co|ah co|look n|Nomi det|a part|color-PRESP n|book'
# 'v|see prep|at det|the n|bottom pro|you mod|can v|see n|fish'
# 'adv|how adj|big aux|be-3S'
# 'adv|where cop|be det|the n|blanket'
# 'co|yeah det|its adj|good prep|for det|your part|dilate-PASTP n|pupil-PL'
# 'co|oh adv|up None|yyy'
# 'pro|what pro|me prep|to co|help'
# 'pro|I v|think n|Nomi aux|be-3S part|tire-PASTP'
# 'None|wee None|wee adj|wee'
# 'adv|good-CP prep|to neg|not v|do pro|it prep|on det|the n|rug adv|how aux|be pro|that co|sweetie'
# 'pro|it cop|be-3S adj|empty'
# 'det|the n|donkey aux|be-3S part|dance-PRESP part|dance-PRESP part|dance-PRESP'
# 'adj|poor n|Goldie'
# 'v|come adv|on pro|here cop|be det|a n|diaper prep|in adv|here n|Naomi'
# 'n|stay prep|in adv|here n|Daddy aux|be part|go-PRESP inf|to v|bring det|the n|paper'
# 'None|I None|think None|she None|has None|better n|Nomi v|say'
# 'co|night_night n|Nomi'
# 'aux|be bab|bit'
# 'co|honey pro|what aux|be-PRES pro|these'
# u'None|mouse n|mouse'
# 'co|yes adv|there pro|it cop|be-3S'
# 'co|yes pro|that cop|be-3S n|Nomi prep|in det|the n|mirror'
# 'pro|that n|dog-DIM poss|s n|tail'
# 'pro|what cop|be-PAST pro|that n|Naomi'
# 'v|read-ZERO det|a n|book'
# 'co|yes n|Daddy'
# 'v|put-ZERO det|the v|coat adv|over adv|here'
# 'pro|that pro|that'
# 'adv|now v|get det|the n|red det|one n|Nomi'
# 'n|dog-DIM None|xxx'
# u'None|house n|house'
# 'adv|here pro|it cop|be-3S n|Nomi det|the n|book cop|be-3S prep|in adv|here'
# 'mod|can pro|you v|say meta|pupil n|Nomi'
# 'pro|they aux|be-PRES part|call-PASTP n|glass-PL'
# 'None|aw pro|that cop|be det|the adj|ease-dn n|way'
# 'v|get pro|that pro|that n|ball'
# 'v|bite-PAST conj|but'
# 'v|put-ZERO det|your n|head adv|down'
# 'aux|be-3S pro|it n|Goldie'
# 'adj|chic aux|be-3S pro|that det|a n|tree'
# 'cop|be-PRES pro|you part|ride-PRESP det|your chi|gogo'
# 'n|blanket n|Nomi'
# 'mod|will pro|you v|come adv|in adv|here coord|and None|we None|will None|play None|with None|mouse pro|we mod|will v|play prep|with det|the n|mouse n|house'
# 'cop|be-3S pro|that det|a n|hat'
# 'v|put-ZERO n|baby prep|in det|the n|boat'
# 'co|no pro|I mod|do neg|not v|think co|so'
# 'pro|that cop|be det|a n|ball'
# 'pro|he aux|be-3S part|go-PRESP prep|to n|turn prep|off det|the n|light-PL'
# 'n|Naomi v|get-PAST adv|up adv|already'
# 'pro|that cop|be adj|neat pro|that pro|you v|turn pro|it coord|and pro|it v|let-3S pro|it v|go'
# 'adv|where cop|be n|dog-DIM poss|s n|tail'
# 'adv|down'
# 'v|come adv|up adv|here det|a n|minute prep|with pro|me'
# 'det|the n|car mod|do-3S neg|not v|have qn|any n|wheel-PL pro|it aux|be part|break-PASTP'
# 'pro|they pro|they'
# 'pro|I v|think n|Mama poss|s part|come-PRESP prep|up det|the n|stair-PL'
# 'pro|that cop|be det|a n|city'
# 'None|eh'
# 'pro|I None|yyy'
# 'det|a n|brush'
# 'qn|no n|red pro|one adj|first n|Nomi'
# 'co|ahhah n|baby coord|and pro|there cop|be det|a n|Mommy'
# 'pro|what aux|be-PRES pro|those'
# 'n|horse-DIM adv|right v|want inf|to v|build det|a n|tower'
# 'det|a adj|empty n|drawer'
# 'n|Daddy n|play'
# 'v|come prep|on co|sweetie'
# 'co|boy None|big None|big adj|big'
# 'pro|I v|want inf|to v|hold pro|you prep|for det|a n|minute'
# 'pro|me adv|down'
# 'v|get det|the n|green det|one adv|over adv|there'
# 'pro|that cop|be adv|too adj|big prep|to n|push n|Nomi'
# 'pro|I aux|be part|try-PRESP inf|to v|get n|word-PL prep|with n|b-PL coord|and n|p-PL adv|now'
# 'adv|how aux|be pro|that n|tower'
# 'co|yes pro|that cop|be det|the n|dog-DIM'
# 'co|yes pro|that cop|be-3S det|a n|house'
# 'co|no pro|it cop|be neg|not det|a n|cow'
# 'mod|do neg|not pro|you v|draw prep|on det|the n|baby'
# 'v|come adv|on prep|in adv|here'
# 'n|Nomi adv|where cop|be-3S n|Mama n|mouse'
# 'v|get det|the n|red pro|one'
# 'pro|that cop|be adj|good pro|I mod|can v|plug pro|it adv|right prep|in adv|here'
# 'mod|do pro|they v|smell adv|pretty'
# 'co|look pro|who cop|be-3S pro|that'
# 'n|fall adv|down'
# 'pro|you v|lie adv|down coord|and v|close pro|those n|eye-PL'
# 'det|a n|house'
# 'mod|do neg|not v|draw qn|no qn|no mod|do neg|not v|draw'
# 'None|baby n|baby'
# 'pro|what v|do-3S det|the n|dog-DIM v|say'
# u'None|pretty adv|pretty'
# 'v|brush det|the n|doll-DIM poss|s n|hair n|Nomi'
# 'pro|that cop|be det|a n|house adv|too co|yes'
# 'pro|what v|do-3S det|the n|pig-DIM v|say'
# 'pro|I mod|can v|put-ZERO det|a None|xxx adv|in adv|here adv|too adv|now pro|I v|think'
# 'n|blanket co|sweetie'
# 'pro|this pro|one adv|here'
# 'co|oh n|Nomi'
# 'pro|what cop|be pro|that n|honey'
# 'n|lie adv|down n|Naomi conj|so pro|we mod|can v|change det|your n|diaper'
# 'n|baby aux|be-3S part|take-PRESP det|a n|nap'
# 'adv|where cop|be det|the n|moon'
# 'pro|that cop|be det|a n|baby'
# 'v|put-ZERO n|Goldie prep|through det|the n|chimney'
# 'pro|what cop|be pro|this det|the n|kitty aux|be-3S part|eat-PRESP n|Nomi'
# 'pro|this adj|little n|pig-DIM v|go-PAST inf|to v|market'
# 'pro|what cop|be pro|that'
# 'v|want inf|to v|go v|see det|the n|snow'
# 'pro|she aux|be adv|over adv|there pro|she cop|be adv|there'
# 'v|let pro|us v|call pro|it None|xxx v|say n|shoe'
# 'n|Goldie'
# 'pro|that cop|be-3S pro|where det|the adj|beautiful n|princess v|live-3S n|Nomi'
# 'co|night_night co|sweetie'
# 'v|show det|the n|dog-DIM'
# 'co|no pro|it cop|be neg|not det|a n|dog-DIM'
# 'pro|this cop|be-3S det|a adj|big n|shoe'
# 'None|yyy pro|me adv|up'
# 'None|dey pro|they pro|they part|do-PASTP'
# 'None|yyy co|no co|oh'
# 'n|horse neg|not det|a n|pig-DIM'
# 'pro|she adv|never v|realize-3S adv|how adj|big det|a n|piece'
# 'pro|what cop|be pro|this n|Nomi'
# 'co|oh co|oh cop|look prep|at pro|it v|spin'
# 'v|go prep|to det|the n|door n|honey'
# 'pro|I v|think-PAST pro|those cop|be-PAST prep|among det|the n|thing-PL pro|that pro|you v|put-ZERO adv|away'
# 'co|look n|Nomi det|the n|car mod|do-3S neg|not v|have qn|any n|wheel-PL prep|on pro|it'
# 'on|oink on|oink pro|here cop|be det|a n|hat'
# 'co|yes pro|that cop|be-3S pro|what det|the n|horse-DIM v|say-3S'
# 'coord|and n|Nomi v|say-3S'
# 'co|yes co|ah co|ah None|xxx adv|pretty co|huh'
# 'co|night_night n|Naomi'
# 'part|break-PASTP'
# 'v|sit adv|down n|brush n|hair'
# 'pro|what'
# 'mod|do-PAST pro|you v|go prep|to det|the n|doctor adv|today'
# 'v|go prep|in det|the n|kitchen coord|and v|see n|Daddy'
# 'pro|what aux|be det|a n|pig-DIM v|say'
# 'pro|you adv|still mod|do neg|not v|have det|your n|slipper prep|on n|babe'
# 'mod|do pro|you v|want det|a n|crayon'
# 'pro|there cop|be det|a n|dog-DIM'
# 'pro|what v|do-3S det|the n|chick-DIM co|say co|sweetie'
# 'v|fall-PAST adv|down adv|again'
# 'n|Goldie co|yeah'
# 'pro|nothing prep|in adv|there'
# 'det|the n|city prep|of n|Burning n|Towers'
# 'co|ah co|oh n|baby'
# 'part|break-PASTP part|break-PASTP'
# 'None|um pro|what aux|be-PRES pro|those'
# 'co|okay adv|now pro|I v|want pro|you inf|to v|say v|say'
# 'None|uh None|uh None|yyy'
# 'None|xxx n|baby'
# 'co|ah adv|down'
# 'n|Daddy n|dog-DIM'
# 'n|Goldie v|fall-PAST adv|down'
# 'v|lay adv|down'
# 'pro|there cop|be det|the n|fish'
# 'None|um None|um'
# 'co|oh det|a adj|little n|drawer'
# 'n|doll-DIM aux|be part|take-PRESP det|a n|nap'
# 'None|xxx mod|do pro|you v|want inf|to v|turn pro|that'
# 'adj|good coord|and det|the n|bird-DIM v|say-3S'
# 'det|a n|book'
# 'n|doll-DIM aux|be part|stick-PRESP adv|up adv|over adv|there'
# 'co|no pro|that cop|be neg|not det|the n|noon n|Naomi'
# 'co|alright n|Nomi pro|I v|want pro|you prep|to n|nap adv|now'
# 'co|hm'
# 'n|slipper n|slipper'
# 'pro|that cop|be n|horse-DIM'
# 'mod|do pro|you v|know pro|what qn|any prep|of pro|those cop|be-PRES'
# 'pro|what aux|be-PRES pro|those n|kitty-PL part|eat-PRESP co|sweetie'
# 'adj|red pro|one'
# 'n|Jerry v|make-PAST pro|that'
# 'qn|no n|sweet pro|you adv|just v|go-PAST n|pot-DIM'
# 'pro|that cop|be det|your n|ear'
# 'co|yeah pro|that cop|be n|Contrary_Mary poss|s n|garden'
# 'det|a n|Little_Miss_Muffet n|Little_Miss_Muffet v|sit-PAST prep|on det|her n|tuffet part|eat-PRESP det|her n|curd-PL coord|and n|whey adv|along v|come-PAST det|a'
# 'pro|this cop|be-3S det|the n|tongue n|Nomi'
# 'pro|what aux|be-PRES det|these n|Nomi'
# 'pro|she v|say-3S n|shoe adv|very adv|nice-dadj adv|now'
# 'adv|how co|oh'
# 'v|put-ZERO adv|down'
# 'pro|there cop|be det|the n|hat'
# 'None|woo bab|woo'
# 'co|yeah part|break-PASTP'
# 'pro|that cop|be n|Nomi'
# 'pro|he pro|that pro|that'
# 'pro|here cop|be det|the n|moon'
# 'pro|that cop|be det|a n|house'
# 'pro|who'
# 'pro|you mod|can v|see det|a n|car adv|out pro|that n|window'
# 'cop|look prep|at pro|that'
# 'coord|and pro|here cop|be det|the n|spider'
# 'det|what v|do n|kitty-PL v|eat'
# 'pro|what aux|be pro|that n|Nomi'
# 'None|um None|yyy'
# 'v|put-ZERO det|the n|blanket prep|on det|the n|baby n|Nomi'
# 'pro|that cop|be adj|dangerous'
# 'pro|I mod|will v|bring det|the n|paper'
# 'mod|do pro|you v|want pro|this pro|one adv|on'
# 'pro|I v|want pro|you inf|to aux|be part|cover-PASTP prep|with det|your n|blanket'
# 'pro|that cop|be det|a n|horse'
# 'pro|you v|have det|one det|two det|three'
# 'adv|how'
# 'co|whoopsie n|Goldie v|fall-PAST adv|down adv|again'
# 'pro|what cop|be pro|this n|honey'
# 'mod|do pro|you v|put-ZERO pro|this prep|on det|the n|floor n|Nomi'
# 'pro|you adv|just v|go-PAST n|pot-DIM adv|now pro|it cop|be-3S v|time inf|to v|go prep|to n|sleep'
# 'adv|how adj|big aux|be-3S n|Nomi'
# 'pro|it cop|be det|a n|horse'
# 'pro|what aux|be det|the n|dog-DIM part|do-PRESP'
# 'pro|that cop|be adj|neat co|huh'
# 'pro|it aux|be part|get-PRESP adv|more coord|and adv|more adj|difficult cop|be-3S neg|not pro|it n|Nomi'
# 'None|rabbit n|rabbit'
# 'co|yes n|Goldie v|write adv|down n|Goldie'
# 'pro|that cop|be adj|red'
# 'v|put-ZERO det|the n|blanket prep|on det|the n|baby'
# 'v|go v|find v|get det|the n|doll-DIM coord|and v|brush det|the n|doll-DIM poss|s n|hair'
# 'pro|there cop|be det|the n|bird-DIM'
# 'adv|where'
# 'cop|be-3S adv|there det|a n|mouse prep|in adv|there'
# 'None|yyy co|hm'
# 'pro|that cop|be det|a n|cow'
# 'pro|you v|lie adv|down adv|too pro|you v|lie adv|down prep|with det|the n|baby'
# 'v|put-ZERO n|Goldie prep|in det|the n|house'
# 'det|a n|shoe'
# 'n|spoon adv|where cop|be det|the n|spoon'
# 'n|towel n|towel n|towel None|yyy'
# 'v|let-ZERO pro|me v|see'
# 'None|xxx adj|good'
# 'n|blanket n|blanket'
# 'n|Nomi mod|can pro|you v|say'
# 'adv|where cop|be det|the n|rabbit poss|s n|hole'
# 'mod|can pro|she v|reach pro|this'
# 'None|gaga bab|gaga'
# 'pro|it aux|be n|Goldie'
# 'co|yes coord|and pro|these cop|be-PRES n|chick-DIM'
# 'pro|what aux|be pro|that n|Naomi'
# 'None|um det|what aux|be-PRES pro|they'
# 'det|a on|oig None|a None|a det|a on|oig on|oig'
# 'n|Daddy co|haha co|haha'
# 'aux|be-3S pro|it det|a n|chicken'
# 'det|a n|puppy'
# 'co|ahhah coord|and det|a n|cow v|say-3S'
# 'co|oh det|the n|blanket'
# 'pro|there cop|be n|Goldie adv|again'
# 'pro|what cop|be-3S pro|this n|Nomi'
# 'co|yes n|Mommy coord|and det|a n|Daddy'
# 'pro|these cop|be-PRES n|flower-PL'
# 'v|go v|see n|Daddy adj|okay n|Naomi v|say pro|something'
# 'n|egg-DIM'
# 'pro|there cop|be pro|one pro|more'
# 'v|put-ZERO det|your n|arm adv|in'
# 'conj|but mod|do neg|not v|use pro|it adv|as det|a n|dust n|cloth n|sweet'
# 'co|oh None|uh co|ugh'
# 'co|okay v|come adv|on v|let-ZERO pro|me v|get pro|you None|xxx adv|here co|sweetie adv|now'
# 'pro|what aux|be-PRES pro|these n|thing-PL None|xxx n|fish'
# 'n|bird-DIM n|bird-DIM'
# 'pro|what aux|be part|break-PASTP n|Nomi'
# 'pro|that cop|be adj|right n|bird-PL cop|be-PRES adv|there'
# 'None|um'
# 'n|baby None|duck n|duck'
#
# ======================================================================
# FAIL: test_word_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-20-64b1fc4815b7>", line 15, in test_word_difference
#     self.assertEqual(set(words_db), set(words_nltk))
# AssertionError: Items in the first set but not the second:
# '&hmm'
# '&aw'
# '&eh'
# '0'
# '&ah'
# '&mm'
# '&um'
# '&uh'
# Items in the second set but not the first:
# 'um'
# 'eh'
# u'mm'
# u'ah'
# u'sipper'
# u'boydie'
# u'dat'
# u'hm'
# u'blankin'
# 'uh'
# 'aw'
# u'whatcha'
#
# ======================================================================
# FAIL: test_word_mor_difference (__main__.NLTKTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-20-64b1fc4815b7>", line 23, in test_word_mor_difference
#     self.assertEqual(set(word_mors_db), set(word_mors_nltk))
# AssertionError: Items in the first set but not the second:
# 'det|this'
# 'adv|actual&dadj-LY'
# 'v|come&PAST'
# 'adv:wh|where~cop|be&3S'
# 'EXC'
# 'v|read&ZERO'
# 'n:prop|Nomi'
# 'n:gerund|say-PRESP'
# 'pro:dem|that'
# 'n|doll-DIM~poss|s'
# 'v|cast-3S'
# 'det|that'
# 'n:let|b-PL'
# 'pro:indef|nothing'
# 'n:prop|Mama~aux|be&3S'
# 'adv:wh|where'
# 'pro:wh|what'
# 'cop|be&3S'
# 'n:prop|Little_Red_Riding_Hood'
# 'v|say&PAST'
# 'pro:exist|there'
# 'adv:wh|how~aux|be&3S'
# 'pro:obj|them'
# 'n|+n|sweet+n|heart'
# 'pro:wh|who'
# 'det:wh|what'
# 'n|tooth&PL'
# 'n:prop|Flipper'
# 'adv|nice&dadj-LY'
# 'v|fit&ZERO'
# 'pro|it~aux|be&3S'
# 'n:prop|Mommy~poss|s'
# 'n|coat'
# 'pro:poss:det|her'
# 'v|+n|night+v|night'
# 'n|down'
# 'mod|do~neg|not'
# 'pro:dem|here'
# 'det:num|three'
# 'pro:indef|one'
# 'pro:sub|she~cop|be&3S'
# 'v|do&3S'
# 'v|put&ZERO'
# 'n:prop|Contrary_Mary~poss|s'
# 'n:prop|Mama~poss|s'
# 'pro:dem|that~cop|be&3S'
# 'n:prop|Towers'
# 'pro:wh|who~cop|be&3S'
# 'n|doll-DIM~aux|be&3S'
# 'pro:indef|something'
# 'aux|be&PRES'
# 'rel|that~aux|be&3S'
# 'n|dog-DIM~poss|s'
# 'cop|be&1S'
# 'rel|whose'
# 'pro:sub|I'
# 'n|egg-DIM-PL'
# 'n|chick-DIM-PL'
# 'aux|have&3S'
# 'adj|care&dn-FULL'
# 'v|do&PAST'
# 'v|look'
# 'n:prop|Mama'
# 'pro:exist|here'
# 'pro:sub|I~mod|will'
# 'pro:indef|more'
# 'NO_UTT'
# 'cop|be&PAST'
# 'pro:poss:det|your'
# 'n:prop|Naomi'
# 'det:num|two'
# 'v|let~pro:obj|us'
# 'adj|good&CP'
# 'pro:sub|we'
# 'cop|be&PRES'
# 'mod|do&3S~neg|not'
# 'pro:wh|what~cop|be&3S'
# 'pro|it~cop|be&3S'
# 'pro:exist|here~cop|be&3S'
# 'pro:wh|what~aux|be&3S'
# 'pro:dem|this'
# 'n:gerund|eat-PRESP'
# 'det|those'
# 'v|sit&PAST'
# 'pro:dem|that~aux|be&3S'
# 'n:prop|Mammy'
# 'part|do&PASTP'
# 'pro:poss:det|my'
# 'n|baby~poss|s'
# 'v|bite&PAST'
# 'n:prop|Mommy'
# 'n:prop|Daddy~aux|be&3S'
# 'aux|be&3S~neg|not'
# 'det:num|one'
# 'n:prop|Jerry'
# 'pro:sub|we~mod|will'
# 'v|see&PAST'
# 'pro:sub|he'
# 'rel|that'
# 'rel|where'
# 'pro|you~mod|will'
# 'n:prop|Burning'
# 'pro:sub|she'
# 'art|a'
# 'v|make&PAST'
# 'rel|who'
# 'n:prop|Grandmother~poss|s'
# 'aux|be&3S'
# 'n:prop|Nana'
# 'pro:poss|mine'
# 'v|hit&ZERO'
# 'v|think&PAST'
# 'n:prop|Chicago'
# 'n:let|p-PL'
# 'n|care-FUL'
# 'adv:wh|how'
# 'pro:exist|there~cop|be&3S'
# 'v|go&PAST'
# 'part|hit&PASTP'
# 'adj|kit&dn-Y'
# 'art|the'
# 'pro:poss:det|its'
# 'BRK'
# 'v|get&PAST'
# 'mod|do&3S'
# 'adv|good&CP'
# 'v|piece-3S'
# 'n:prop|Daddy'
# 'mod:aux|have_to'
# 'adj|ease&dn-Y'
# 'n:let|r'
# 'pro:dem|those'
# 'pro:dem|these'
# 'n:let|n'
# 'n:let|i'
# 'n:let|d'
# 'n:let|e'
# 'v|stay'
# 'pro:sub|I~aux|be&1S'
# 'n:prop|Dadda'
# 'n|dog~poss|s'
# 'v|let&ZERO'
# 'pro:obj|me'
# 'v|lie-3S'
# 'adv:tem|today'
# 'part|break&PASTP'
# 'v|fall&PAST'
# 'mod|will~neg|not'
# 'n|sweet&dadj-DIM'
# 'pro:sub|we~cop|be&PRES'
# 'pro:sub|they'
# 'n|rabbit~poss|s'
# 'pro:wh|what~poss|s'
# 'pro:dem|there'
# 'co|sweetheart'
# 'mod|will&COND'
# 'n:prop|Little_Miss_Muffet'
# 'cop|be&PAST&13S'
# 'adj|lay'
# 'n:prop|Goldie'
# Items in the second set but not the first:
# 'v|fall-PAST'
# 'n|Little_Red_Riding_Hood'
# 'None|house'
# 'None|will'
# 'n|b-PL'
# 'v|make-PAST'
# 'pro|I'
# 'n|dog'
# 'None|play'
# 'mod|have_to'
# 'n|Jerry'
# 'None|with'
# 'det|one'
# 'pro|something'
# 'det|her'
# 'None|dey'
# 'cop|look'
# 'v|read-ZERO'
# 'None|baby'
# 'v|fit-ZERO'
# 'pro|what-PRES'
# 'None|we'
# 'n|smell'
# 'v|come-PAST'
# 'co|mm'
# 'adj|ease-dn'
# 'None|how'
# u'None|mouse'
# 'n|Nomi'
# 'n|Little_Miss_Muffet'
# 'aux|be-1S'
# 'v|coat'
# 'None|rabbit'
# 'None|oig'
# 'adv|where'
# 'cop|be-PAST'
# 'pro|those'
# 'co|hm'
# 'v|get-PAST'
# 'aux|have-3S'
# 'adv|actual-dadj'
# 'v|do-3S'
# 'n|d'
# 'n|tooth-PL'
# 'mod|do-3S'
# 'adj|good-CP'
# 'v|night'
# 'pro|he'
# 'adv|good-CP'
# 'v|think-PAST'
# 'pro|more'
# 'det|its'
# 'det|what'
# 'n|Dadda'
# 'pro|this'
# 'n|e'
# 'None|I'
# 'n|i'
# 'None|up'
# 'pro|she'
# 'n|n'
# 'pro|where'
# 'None|uh'
# 'n|r'
# 'None|um'
# 'mod|will-COND'
# 'pro|that'
# 'n|Daddy'
# 'None|eh'
# 'pro|her'
# 'None|she'
# 'None|yyy'
# 'None|a'
# 'None|bye'
# 'None|better'
# 'n|say-PRESP'
# 'v|do-PAST'
# 'det|my'
# 'n|p-PL'
# 'v|flower-3S'
# 'adv|how'
# 'n|Contrary_Mary'
# 'n|Mommy'
# 'None|wee'
# 'part|break-PASTP'
# 'det|your'
# 'n|Naomi'
# 'co|ah'
# 'n|egg-DIM'
# 'pro|these'
# 'None|Daddy'
# 'pro|us'
# 'None|think'
# 'None|car'
# 'n|Grandmother'
# 'pro|one'
# 'pro|nothing'
# u'None|and'
# 'mod|do-PAST'
# 'cop|be-PRES'
# 'pro|who'
# 'v|baby'
# 'v|say-PAST'
# 'v|let'
# 'n|Mama'
# 'n|Nana'
# 'n|sweet'
# 'adj|alright'
# 'None|woo'
# 'det|three'
# 'pro|there'
# 'None|xxx'
# 'v|bite-PAST'
# 'pro|whose'
# 'det|two'
# 'pro|mine'
# 'part|do-PASTP'
# 'poss|s'
# 'None|has'
# 'n|cast-PL'
# 'aux|be-3S'
# 'None|duck'
# 'cop|be-3S'
# 'pro|we'
# u'None|pretty'
# 'v|go-PAST'
# 'adv|nice-dadj'
# 'n|Goldie'
# 'n|Towers'
# 'v|hit-ZERO'
# 'det|the'
# 'pro|here'
# 'v|let-ZERO'
# 'n|Burning'
# 'pro|them'
# 'None|truck'
# 'v|see-PAST'
# 'adv|today'
# 'aux|be-PRES'
# 'None|gaga'
# 'pro|they'
# 'n|piece-PL'
# 'part|hit-PASTP'
# 'n|Chicago'
# 'v|sit-PAST'
# 'None|hat'
# 'pro|me'
# 'None|ah'
# 'None|aw'
# 'None|big'
# 'v|lay'
# 'v|put-ZERO'
# 'det|a'
# 'n|Flipper'
# 'n|Mammy'
# 'pro|what'
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.586s
#
# FAILED (failures=4)
# <unittest.runner.TextTestResult run=4 errors=0 failures=4>
